# %% [markdown]
# ###Download the Dataset

# %%
# !!curl -O http://www.manythings.org/anki/ara-eng.zip
# !!unzip ara-eng.zip
# Out:
# ['Archive:  ara-eng.zip',
#  '  inflating: _about.txt              ',
#  '  inflating: ara.txt                 ']

# %% [markdown]
# ###Import the Libraries

# %%
import pandas as pd
from nltk.translate.bleu_score import sentence_bleu
import numpy as np
import string
from string import digits
import matplotlib.pyplot as plt
# %matplotlib inline
import re
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras.layers import Input, LSTM, Embedding, Dense,Dropout
from keras.models import Model
from numpy import array
from numpy import asarray
from numpy import zeros
import keras
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.bleu_score import corpus_bleu

# %% [markdown]
# ###Dataset Importing and Visualization

# %%
# Path to the data txt file on disk.
data_path = "ara.txt"
# open the file eng-spa.txt and read
lines= pd.read_table(data_path,  names =['source', 'target', 'comments'])
#printing sample data from lines
lines.sample(6)
# Out:
#                                               source  ...                                           comments
# 6879                  A dolphin is a kind of mammal.  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #6...
# 10702  Though it was cold, he didn't light the fire.  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 6694                   I'm not telling you anything.  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #1...
# 10634  He extorted a large amount of money from her.  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #3...
# 4264                         I was made to go there.  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 9034             She put down her thoughts on paper.  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #3...
#
# [6 rows x 3 columns]

# %%
lines.shape
# Out:
# (11668, 3)

# %%
lines.head(3)
# Out:
#   source   target                                           comments
# 0    Hi.  مرحبًا.  CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 1   Run!    اركض!  CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 2  Help!  النجدة!  CC-BY 2.0 (France) Attribution: tatoeba.org #4...

# %%
lines[11665:11668]
# Out:
#                                                   source  ...                                           comments
# 11665  A man touched down on the moon. A wall came do...  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #3...
# 11666  Ladies and gentlemen, please stand for the nat...  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #3...
# 11667  There are mothers and fathers who will lie awa...  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #3...
#
# [3 rows x 3 columns]

# %%
lines.source[11665]
# Out:
# 'A man touched down on the moon. A wall came down in Berlin. A world was connected by our own science and imagination.'

# %%
lines.target[11665]
# Out:
# 'هبط إنسان على سطح القمر، وأنهار حائط في برلين، و عالم ترابطت أجزاؤه بعلمنا وخيالنا.'

# %%
lines.source[11666]
# Out:
# 'Ladies and gentlemen, please stand for the national anthem of the Russian Federation performed by the Sretensky Monastery Choir.'

# %%
lines.target[11666]
# Out:
# 'سيداتي و سادتي ، رجاءً قفوا للنشيد الوطني للاتحاد الروسي باداء جوقة دير سرتينسكي .'

# %%
lines.source[11667]
# Out:
# "There are mothers and fathers who will lie awake after the children fall asleep and wonder how they'll make the mortgage, or pay their doctor's bills, or save enough for their child's college education."

# %%
lines.target[11667]
# Out:
# 'وهناك أمهات وآباء سيظلون مستيقظين بعد أن ينام أطفالهم، يتساءلون عن كيف سيسددون أقساط الرهن العقاري الذي اشترَوْ به بيتهم، وكيف سيدفعون فواتير أطبائهم، أو توفير ما يحتاجونه من مال لتسديد رسوم تسجيل أبنائهم في الجامعات.'

# %%
len(lines)
# Out:
# 11668

# %% [markdown]
# ###Dataset Cleaning

# %%
# convert source and target text to Lowercase 
lines.source=lines.source.apply(lambda x: x.lower())
lines.target=lines.target.apply(lambda x: x.lower())
# Remove quotes from source and target text
lines.source=lines.source.apply(lambda x: re.sub("'", '', x))
lines.target=lines.target.apply(lambda x: re.sub("'", '', x))
# create a set of all special characters
special_characters= set(string.punctuation)
# Remove all the special characters
lines.source = lines.source.apply(lambda x: ''.join(char1 for char1 in x if char1 not in special_characters))
lines.target = lines.target.apply(lambda x: ''.join(char1 for char1 in x if char1 not in special_characters))
# Remove digits from source and target sentences
num_digits= str.maketrans('','', digits)
lines.source=lines.source.apply(lambda x: x.translate(num_digits))
lines.target= lines.target.apply(lambda x: x.translate(num_digits))
# Remove extra spaces
lines.source=lines.source.apply(lambda x: x.strip())
lines.target=lines.target.apply(lambda x: x.strip())
lines.source=lines.source.apply(lambda x: re.sub(" +", " ", x))
lines.target=lines.target.apply(lambda x: re.sub(" +", " ", x))
lines.source=lines.source.apply(lambda x: re.sub("[^-9A-Za-z ]", "" , x))

# %%
def clean_text_english(text):
    '''Clean text by removing unnecessary characters and altering the format of words.'''

    text = text.lower()
    
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"it's", "it is", text)
    text = re.sub(r"that's", "that is", text)
    text = re.sub(r"what's", "that is", text)
    text = re.sub(r"where's", "where is", text)
    text = re.sub(r"how's", "how is", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"can't", "cannot", text)
    text = re.sub(r"n't", " not", text)
    text = re.sub(r"n'", "ng", text)
    text = re.sub(r"'bout", "about", text)
    text = re.sub(r"'til", "until", text)
    text = re.sub(r"[-()\"#/@;:<>{}`+=~|.!?,]", "", text)
    
    return text
lines.source=lines.source.apply(clean_text_english)
lines.source=lines.source.apply(lambda x: re.sub("[.?#@%^&*()@!;:'\/!*]", "", x))

# %%
lines.target=lines.target.apply(lambda x: re.sub("[٠١٢٣٤٥٦٧٨٩۱۹۰]", "", x))
lines.target=lines.target.apply(lambda x: re.sub("[ـ،؛؟٫٬٠]", "", x))
lines.target=lines.target.apply(lambda x: re.sub("[abcdefghijklmnopqrstuvwxyz]", "", x))
# adapted from https://github.com/bakrianoo/aravec
# function to clean and normalize text 
def clean_text(text):
    search = ["أ","إ","آ","ة","_","-","/",".","،"," و "," يا ",'"',"ـ","'","ى","\\",'\n', '\t','&quot;','?','؟','!']
    replace = ["ا","ا","ا","ه"," "," ","","",""," و"," يا","","","","ي","",' ', ' ',' ',' ? ',' ؟ ',' ! ']  
    p_tashkeel = re.compile(r'[\u0617-\u061A\u064B-\u0652]')
    text = re.sub(p_tashkeel,"", text)
    p_longation = re.compile(r'(.)\1+')
    subst = r"\1\1"
    text = re.sub(p_longation, subst, text)
    text = text.replace('وو', 'و')
    text = text.replace('يي', 'ي')
    text = text.replace('اا', 'ا')
    
    for i in range(0, len(search)):
        text = text.replace(search[i], replace[i])
        
    text = text.strip()
    
    return text
lines.target=lines.target.apply(clean_text)

# %%
def remove_diacritics(text):
    arabic_diacritics = re.compile(""" ّ    | # Tashdid
                             َ    | # Fatha
                             ً    | # Tanwin Fath
                             ُ    | # Damma
                             ٌ    | # Tanwin Damm
                             ِ    | # Kasra
                             ٍ    | # Tanwin Kasr
                             ْ    | # Sukun
                             ـ     # Tatwil/Kashida
                         """, re.VERBOSE)
    text = re.sub(arabic_diacritics, '', str(text))
    return text

# %%
lines.target=lines.target.apply(remove_diacritics)

# %%
# Add start and end tokens to target sequences
lines.target = lines.target.apply(lambda x : 'START_ '+ x + ' _END')
lines.sample(6)
# Out:
#                                                  source  ...                                           comments
# 9742              the question is where to buy the book  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #3...
# 8836                  tom will probably not believe you  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 11003  the band upped the number of shows in their tour  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #3...
# 4646                            i have the ace of clubs  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 1675                                   she was promoted  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #3...
# 7526                     my mother plays the piano well  ...  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
#
# [6 rows x 3 columns]

# %% [markdown]
# ###Tokenization

# %%
# Find all the source and target words and sort them
# Vocabulary of Source language
all_source_words=set()
for source in lines.source:
    for word in source.split():
        if word not in all_source_words:
            all_source_words.add(word)
# Vocabulary of Target 
all_target_words=set()
for target in lines.target:
    for word in target.split():
        if word not in all_target_words:
            all_target_words.add(word)
# sort all unique source and target words
source_words= sorted(list(all_source_words))
target_words=sorted(list(all_target_words))

# %%
for i in source_words:
   print(i)
# Out:
# a
# abandon
# ability
# able
# aboard
# abomination
# abortion
# about
# above
# abroad
# absence
# absent
# absolute
# absolutely
# absorb
# abuse
# abused
# abusing
# accelerated
# accent
# accept
# accepted
# accepting
# accident
# accidents
# accompanies
# accompany
# accomplished
# account
# accurate
# accused
# accustomed
# ace
# aces
# ache
# achieved
# achilles
# acknowledge
# acquaintance
# acquainted
# acquisition
# across
# act
# acting
# action
# actions
# active
# actor
# actress
# acts
# actually
# adapted
# add
# added
# addicted
# address
# addressed
# adjust
# adjusting
# admire
# admit
# adopt
# ads
# adults
# advance
# advances
# advantage
# adventure
# adversity
# advertisements
# advice
# advise
# advised
# affair
# affect
# affected
# afford
# afraid
# africa
# after
# afterlife
# afternoon
# again
# against
# age
# agency
# ago
# agree
# agreed
# agrees
# ahead
# aid
# aim
# aimed
# aint
# air
# airmail
# airplane
# airport
# alarm
# albert
# alcohol
# alert
# alexandria
# alike
# alive
# all
# allergic
# allergy
# alley
# allow
# allowance
# allowed
# almost
# alone
# along
# aloud
# already
# also
# alter
# alternative
# although
# always
# am
# amazes
# amazing
# ambassador
# ambition
# ambulance
# america
# american
# americans
# amiss
# among
# amount
# amplifier
# amused
# an
# ancestors
# ancient
# and
# angel
# anger
# angry
# animal
# animals
# annexed
# announced
# annoying
# another
# answer
# answered
# answering
# ant
# anthem
# anticipating
# anticonstitutionnellement
# ants
# anxious
# any
# anybody
# anymore
# anyone
# anything
# anytime
# anyway
# anyways
# anywhere
# apart
# apartment
# apologies
# apologize
# apologized
# apology
# apparent
# apparently
# appear
# appearance
# appearances
# appeared
# appears
# applauded
# apple
# apples
# application
# applications
# appointment
# appreciate
# appreciates
# appreciation
# approached
# appropriate
# approve
# approved
# april
# arab
# arabic
# arabs
# arbitrarily
# arctic
# are
# area
# arent
# argentine
# argue
# arguing
# arm
# army
# around
# arrangements
# arrested
# arrive
# arrived
# arrives
# arriving
# arrogance
# art
# article
# articles
# artificial
# artist
# artists
# as
# asakusa
# asap
# ashamed
# asia
# aside
# ask
# asked
# asking
# asks
# asleep
# assist
# assume
# assumed
# astronaut
# astronomy
# astrophysicist
# at
# ate
# atlantis
# atomic
# attached
# attack
# attacked
# attempt
# attempted
# attempts
# attend
# attended
# attention
# attic
# attitude
# attracted
# attraction
# attractions
# audience
# aunt
# australia
# austria
# author
# authorities
# authority
# automatic
# automatically
# autumn
# available
# avenged
# avenue
# avocados
# avoid
# await
# awake
# award
# aware
# away
# awesome
# awkward
# babies
# baby
# babys
# babysitter
# back
# backfired
# backup
# bad
# badly
# baffled
# bag
# bags
# baked
# baker
# bald
# ball
# balls
# bananas
# band
# bandage
# bangkok
# bank
# banquet
# bar
# barged
# barked
# barking
# barley
# barn
# baseball
# based
# basket
# basketball
# bat
# bath
# bathroom
# bathtub
# bats
# battle
# be
# beach
# beak
# bear
# bears
# beat
# beautiful
# beauty
# became
# because
# become
# becoming
# bed
# bedroom
# bedtime
# been
# beer
# bees
# before
# beg
# began
# begging
# begin
# beginner
# beginners
# beginning
# begins
# begun
# behave
# behaved
# behaving
# behavior
# behind
# beijing
# being
# belgium
# believe
# believed
# believes
# bell
# belong
# belongs
# belt
# bench
# benefit
# bent
# berlin
# beside
# best
# bet
# betray
# betrayed
# better
# between
# beyond
# bible
# bicycle
# big
# bigger
# biggest
# bike
# biking
# bill
# billion
# bills
# biologist
# biology
# bird
# birds
# birth
# birthday
# bit
# bite
# bitten
# bitterly
# black
# blackboard
# blame
# blanket
# bleeding
# bless
# blessing
# blind
# blocked
# blondes
# blood
# bloom
# blowing
# blue
# board
# boarding
# boat
# bodies
# body
# boil
# bomb
# bombed
# bones
# book
# books
# border
# bore
# bored
# boring
# born
# borrow
# borrowed
# boss
# boston
# both
# bother
# bothered
# bothering
# bothers
# bottle
# bottles
# bottom
# bottoms
# bought
# bowling
# box
# boxer
# boxes
# boy
# boyfriend
# boys
# bracelet
# brake
# brakes
# brand
# brave
# bravely
# brazil
# brazilian
# bread
# break
# breakfast
# breaking
# breast
# breath
# breathe
# breathless
# breed
# bribes
# bridge
# briefcase
# bright
# brilliant
# brim
# bring
# britain
# british
# broadens
# broke
# broken
# brokendown
# brother
# brothers
# brought
# brown
# browser
# brunettes
# brush
# brushes
# buddy
# budget
# bug
# build
# building
# built
# bullet
# bulletproof
# bunch
# burial
# buried
# burn
# burned
# burning
# burns
# burst
# bus
# bush
# busiest
# business
# businesses
# businessmen
# busy
# but
# butcher
# butchers
# butter
# butterfly
# buy
# buys
# by
# bye
# c
# cab
# cage
# caged
# cairo
# cake
# calculate
# calculated
# california
# call
# called
# calling
# calls
# calm
# calmed
# calories
# came
# camera
# cameras
# camping
# campus
# can
# canada
# canadians
# canaries
# cancel
# canceled
# cancer
# candlelight
# candy
# cannot
# cant
# canyon
# cap
# capable
# capacity
# capital
# captain
# captured
# car
# card
# cards
# care
# careful
# carefully
# careless
# cares
# cargo
# carp
# carried
# carries
# carrots
# carry
# cars
# case
# cash
# castle
# castles
# cat
# catch
# catches
# catholic
# cats
# cattle
# caught
# cause
# caused
# causes
# cave
# caviar
# cd
# cds
# ceasefire
# ceiling
# celebration
# cell
# celsius
# center
# century
# ceremony
# certain
# certainly
# chair
# challenge
# challenges
# champagne
# champion
# chance
# chances
# change
# changed
# changes
# changing
# channel
# character
# charge
# charges
# charging
# charity
# cheap
# cheaper
# cheat
# cheating
# check
# checked
# cheer
# cheerful
# cheerfully
# cheers
# cheese
# cheeseburgers
# chemical
# chemistry
# cherries
# chess
# chest
# chew
# chicken
# chief
# child
# childhood
# children
# childs
# china
# chinese
# chocolate
# choice
# choir
# cholesterol
# choose
# chose
# christianity
# christmas
# church
# cigarette
# circle
# circumstances
# cities
# citizen
# citizens
# city
# claimed
# claims
# clapping
# clapton
# class
# classes
# classical
# classmate
# classmates
# classroom
# claus
# clean
# cleaned
# cleaner
# cleaning
# clear
# clearing
# clearly
# clever
# cliff
# climate
# climb
# climbed
# climbers
# clinic
# clip
# clock
# close
# closed
# closely
# closer
# closest
# cloth
# clothes
# clothing
# cloud
# clouds
# club
# clubs
# clues
# clutch
# coach
# coaches
# coat
# cobras
# cocktail
# coffee
# coin
# coins
# cola
# cold
# colder
# colds
# collapse
# collapsed
# collecting
# collection
# collects
# college
# collisions
# color
# colors
# columbia
# comb
# combined
# come
# comes
# comfort
# comfortable
# comic
# coming
# command
# comment
# comments
# commercial
# committed
# committee
# common
# communicate
# communism
# communities
# company
# compare
# comparison
# competed
# competition
# complain
# complained
# complaining
# complains
# complete
# completely
# completion
# complex
# complicated
# computer
# computers
# computersavvy
# concentrate
# concentrated
# concern
# concerned
# concert
# concluded
# condition
# conditioner
# conditions
# conduct
# conference
# confess
# conflict
# confront
# confronted
# confused
# confusing
# congratulate
# congratulated
# congratulations
# congress
# connected
# connection
# conscience
# consciousness
# consequence
# consequences
# conservative
# consider
# considerable
# consideration
# consists
# constant
# constantly
# construction
# consult
# consulting
# consumption
# contact
# contain
# contains
# content
# contest
# context
# continue
# continued
# contract
# contracted
# contrary
# contribute
# control
# convenient
# conversation
# converse
# converted
# conviction
# convince
# convinced
# cook
# cooked
# cookie
# cookies
# cooking
# cool
# cooperation
# cope
# copies
# cops
# copy
# copyrighted
# corner
# correct
# cost
# costly
# costs
# cotton
# couch
# cough
# could
# couldnt
# couldve
# council
# count
# counting
# countries
# country
# counts
# couple
# courage
# course
# court
# cousin
# cousins
# cover
# coverage
# covered
# cow
# coward
# coworkers
# cows
# craftsman
# crash
# crashed
# crawling
# crazy
# cream
# created
# creative
# creativity
# creature
# credit
# cremated
# cricket
# cried
# crime
# crimes
# crisis
# critic
# critical
# croatia
# crocodile
# crop
# cross
# crossed
# crowd
# crowded
# crown
# cruel
# crushed
# cry
# crying
# culture
# cup
# cured
# curious
# curry
# curtain
# customer
# customs
# cut
# cute
# cutting
# dad
# daddy
# daily
# damacus
# damage
# damaged
# damages
# damaging
# damp
# dance
# dancing
# danger
# dangerous
# dare
# daredevil
# dark
# dartboard
# darwin
# date
# dates
# dating
# daughter
# daughters
# dawn
# day
# days
# dead
# deadly
# deaf
# deal
# deals
# dealt
# death
# debt
# debts
# deceased
# deceived
# december
# decide
# decided
# deciding
# decision
# decisions
# declined
# decreasing
# deep
# deepest
# deeply
# deer
# defeat
# defend
# definite
# definitely
# degrees
# delayed
# delete
# deleted
# delicious
# deliver
# delivery
# demand
# demanded
# demanding
# democracy
# demonstration
# denied
# dent
# dentist
# deny
# depend
# dependable
# dependent
# depending
# depends
# depressed
# depression
# deprive
# deprived
# derived
# describe
# deserted
# deserve
# deserved
# deserves
# design
# designed
# designer
# desire
# desk
# desks
# despise
# despised
# despises
# dessert
# destination
# destiny
# destroy
# destroyed
# details
# detectives
# determined
# device
# devoted
# devoured
# devout
# dialed
# diamonds
# diary
# dictionaries
# dictionary
# did
# didnt
# die
# died
# dies
# diet
# difference
# different
# differs
# difficult
# difficulties
# difficulty
# dig
# digging
# dining
# dinner
# dinosaur
# dip
# diplomats
# dipped
# dipping
# direct
# direction
# directions
# directly
# directory
# dirt
# disagree
# disappeared
# disappoint
# disappointed
# disappointment
# disclosed
# discovered
# discreet
# discuss
# discussed
# disease
# disgusting
# dish
# dishes
# dishonest
# dislike
# disliked
# dislikes
# disobey
# dispensed
# dispute
# disregarded
# distance
# distances
# distinctive
# distinguish
# disturb
# dived
# divided
# divorce
# divorced
# dizzy
# dna
# do
# doable
# doctor
# doctors
# document
# documents
# does
# doesnt
# dog
# dogs
# doing
# doll
# dollar
# dollars
# dolphin
# done
# dont
# door
# doors
# doubt
# doubted
# dough
# down
# downtown
# dozed
# dozen
# dr
# dragon
# drank
# draw
# drawing
# dreaded
# dream
# dreams
# dress
# dressed
# dresses
# drew
# drink
# drinkable
# drinking
# drinks
# drive
# driver
# drivers
# drives
# driving
# drop
# dropped
# drove
# drowned
# drowning
# drug
# drugstore
# drum
# drunk
# drunken
# dry
# dudes
# due
# dug
# dumb
# during
# dust
# duties
# duty
# dying
# each
# eagerly
# earlier
# early
# earned
# ears
# earth
# earthquake
# earthquakes
# ease
# easily
# eastern
# easy
# eat
# eaten
# eating
# eats
# economic
# economical
# economically
# economies
# economy
# ecuador
# edge
# education
# effect
# effort
# efforts
# egg
# eggs
# egypt
# eight
# eighteen
# eighth
# eightthirty
# eightyone
# einsteins
# either
# elect
# elected
# electricity
# electronic
# element
# elephant
# elephants
# elevator
# eleven
# else
# elses
# em
# email
# embarrassed
# embarrassing
# embassy
# emerged
# emergency
# emotional
# emotions
# employs
# empty
# encourage
# encouraged
# end
# endangered
# ended
# ending
# endless
# ends
# endure
# enemies
# enemy
# energy
# engine
# engineers
# england
# english
# englishmen
# enjoy
# enjoyed
# enormous
# enough
# enter
# entered
# entering
# entire
# entirely
# entrance
# entree
# envelope
# envy
# episode
# equals
# eric
# err
# error
# errors
# escape
# escaped
# essential
# europe
# european
# europeans
# even
# evening
# event
# eventually
# ever
# everett
# every
# everybody
# everyday
# everyone
# everything
# everythings
# everywhere
# evidence
# evil
# exact
# exactly
# exaggerate
# exaggerating
# exam
# examination
# examined
# example
# excelled
# excellent
# excels
# except
# exceptions
# exchange
# exchanged
# excuse
# excused
# exemption
# exercise
# exhausted
# exhibition
# exist
# existence
# exit
# expect
# expected
# expecting
# expelled
# expense
# expenses
# expensive
# experience
# experiment
# expert
# experts
# expires
# explain
# explanation
# exploded
# explored
# express
# expressed
# exquisite
# extorted
# extra
# extraordinarily
# extraordinary
# extremely
# extremism
# eye
# eyes
# eyesight
# face
# facebook
# facing
# fact
# factories
# factors
# factory
# facts
# fail
# failed
# failing
# fails
# failure
# fair
# fairly
# fairy
# faith
# fall
# fallen
# falling
# false
# familiar
# family
# famous
# fantastic
# fantasy
# far
# farm
# farmers
# fascinated
# fascinating
# fashion
# fast
# fasten
# faster
# fastest
# fastfood
# fat
# fate
# father
# fathers
# fattening
# faucet
# faucets
# fault
# favor
# favorite
# favorites
# fax
# fear
# feast
# feather
# february
# fed
# federation
# feed
# feel
# feeling
# feelings
# feels
# feet
# fell
# felt
# female
# fence
# fetch
# fever
# few
# fewer
# fiber
# fierce
# fifteen
# fifteenth
# fifth
# fifty
# fiftygallons
# fight
# fighter
# fighting
# figure
# figured
# figures
# file
# filing
# fill
# filled
# film
# final
# finally
# financial
# find
# finding
# finds
# fine
# finger
# fingerprint
# finish
# finished
# fire
# fired
# firefighter
# firefox
# fireplace
# fireworks
# firm
# firmly
# first
# fish
# fishing
# fit
# five
# fivestar
# fix
# fixed
# flag
# flags
# flame
# flames
# flat
# flavoring
# flew
# flexible
# flip
# float
# floats
# flock
# flood
# floor
# floors
# florence
# florida
# flower
# flowers
# flu
# fluent
# fluently
# fluoride
# flute
# fly
# flying
# focused
# folder
# follow
# followed
# following
# follows
# fonder
# food
# fool
# fooled
# foolish
# foot
# football
# for
# force
# forced
# forces
# ford
# forehead
# foreign
# forever
# forget
# forgetful
# forgets
# forgetting
# forgive
# forgiven
# forgot
# forgotten
# fork
# form
# formal
# formed
# forms
# formula
# fortunate
# fortunately
# forty
# fortysix
# forward
# fought
# foul
# found
# founded
# fountain
# four
# fox
# foxes
# france
# francisco
# frankly
# freaked
# free
# freedom
# freeze
# freezes
# freezing
# french
# frenchman
# frequently
# fresh
# friday
# fridays
# friend
# friendly
# friends
# friendship
# frightened
# frisbee
# fritz
# from
# front
# frowned
# frozen
# fruit
# fruits
# fuel
# fuji
# fulfill
# full
# fulltime
# fun
# funeral
# funny
# furniture
# further
# future
# gain
# gaining
# gallery
# game
# games
# gang
# garage
# garbage
# garden
# gardener
# gas
# gasoline
# gate
# gave
# gawking
# gay
# general
# generalizations
# generally
# genius
# gentlemen
# george
# german
# germany
# get
# gets
# getting
# ghost
# ghosts
# giant
# gift
# gifts
# giftwrap
# gigantic
# girl
# girlfriend
# girls
# give
# given
# gives
# giving
# glad
# gladly
# glanced
# glass
# glasses
# glimpse
# global
# gloomy
# gloves
# glowed
# go
# goal
# goat
# god
# gods
# goes
# going
# gold
# golden
# golf
# gone
# good
# goodbye
# goodnight
# goods
# gossipers
# got
# gotten
# governed
# government
# gown
# grab
# grade
# grader
# grades
# graduate
# graduated
# graduation
# grand
# grandfather
# grandmother
# grandmothers
# grandparents
# granite
# grapes
# grass
# grateful
# gratitude
# grave
# graves
# gravity
# greasy
# great
# greatest
# greatly
# greece
# greed
# greek
# green
# greeted
# grew
# grilling
# ground
# group
# groups
# grow
# growing
# grown
# grows
# guacamole
# guarantee
# guard
# guess
# guest
# guests
# guide
# guilty
# guitar
# gums
# gun
# guns
# guy
# guys
# gym
# habit
# habits
# hacked
# had
# hadnt
# hair
# haircut
# hairdressers
# hairs
# hairstyle
# half
# halloween
# hamburgers
# hamlet
# hammer
# hand
# handbag
# handed
# handle
# hands
# handsome
# handwriting
# hang
# happen
# happened
# happening
# happens
# happiness
# happy
# harbor
# hard
# harder
# hardest
# hardly
# hardworking
# harm
# harsh
# harvard
# has
# hasnt
# hat
# hate
# hated
# hates
# hats
# haunted
# have
# havent
# having
# hawaii
# haystack
# he
# head
# headache
# headed
# health
# healthy
# hear
# heard
# hearing
# heart
# heartbroken
# hearts
# heat
# heating
# heaven
# heavier
# heavily
# heavy
# hed
# height
# held
# helicopter
# helicopters
# hell
# hello
# help
# helped
# helpful
# helping
# helps
# hens
# her
# here
# heres
# heritage
# hero
# hers
# herself
# hes
# hesitated
# hey
# hi
# hid
# hide
# hiding
# high
# higher
# hijackers
# hill
# hills
# him
# himself
# hire
# his
# history
# hit
# hitler
# hitting
# hobby
# hockey
# hokkaido
# hold
# hole
# holiday
# holidays
# home
# homer
# homesick
# hometown
# homework
# honest
# honesty
# honey
# hong
# honolulu
# honors
# hope
# hopefully
# hopeless
# hopes
# hoping
# horizons
# horrible
# horror
# horse
# horses
# hospital
# hospitals
# hostage
# hostages
# hot
# hotel
# hotels
# hour
# hours
# house
# household
# houses
# housewives
# housework
# how
# hows
# hug
# huge
# hugged
# human
# humanity
# humans
# hundred
# hundreds
# hung
# hunger
# hungry
# hunt
# hunter
# hurried
# hurry
# hurt
# hurts
# husband
# hydrogen
# i
# ice
# iceberg
# icelandic
# icy
# id
# idea
# ideal
# ideas
# identical
# idiot
# idiots
# if
# ignorance
# ignore
# ignoring
# ill
# illegal
# illegally
# illness
# im
# imaginary
# imagination
# imagined
# imitation
# immature
# immediately
# immortal
# immune
# immunity
# impact
# impolite
# importance
# important
# imported
# imports
# impossible
# impressed
# impression
# improve
# improved
# improving
# in
# incident
# including
# income
# inconvenience
# increase
# increased
# increasing
# incredible
# indebted
# indeed
# indefinitely
# independence
# independent
# india
# indicate
# indicted
# indiscretions
# indispensable
# indisputable
# industrial
# industry
# influenced
# inform
# information
# injured
# injury
# innocence
# innocent
# insects
# insert
# inside
# insist
# instantly
# instead
# instigated
# instrument
# insult
# insulted
# insurance
# intelligent
# intend
# intent
# intention
# intentionally
# intentions
# interest
# interested
# interesting
# interests
# international
# internet
# interrupt
# interrupted
# interrupting
# interruption
# intervene
# interview
# interviewed
# into
# intriguing
# introduce
# introduced
# invaded
# invaluable
# invented
# investigating
# investigation
# invitation
# invite
# invited
# inviting
# involved
# iraq
# iron
# ironed
# irritating
# is
# islam
# island
# islands
# isnt
# issue
# issued
# issues
# istanbul
# it
# italian
# italy
# itches
# itchy
# itd
# itll
# its
# itself
# ive
# jacket
# jackson
# jacksons
# jail
# jam
# january
# japan
# japanese
# jar
# jazz
# jello
# jesus
# jet
# jets
# job
# jobs
# john
# johns
# join
# joins
# joints
# joke
# joking
# journey
# judaism
# judge
# judges
# judging
# judgment
# judgmental
# juice
# july
# jump
# jumped
# june
# jungle
# junior
# jury
# just
# justifies
# kaddafi
# kangaroo
# karim
# karuizawa
# kebab
# keep
# keeps
# kelly
# kenya
# kept
# key
# keys
# kickbacks
# kicked
# kid
# kidding
# kidnappers
# kids
# kill
# killed
# killer
# kilo
# kilometers
# kind
# kindly
# kindness
# kinds
# king
# kiss
# kissed
# kitchen
# kites
# knew
# knife
# knit
# knock
# knockout
# know
# knowing
# knowledge
# known
# knows
# koala
# kong
# korea
# korean
# kuala
# kyiv
# kyoto
# lab
# lack
# lacking
# ladder
# ladies
# lady
# laid
# lake
# land
# landed
# landing
# language
# languages
# large
# larger
# largest
# lasagna
# last
# lasted
# late
# lately
# later
# latin
# laughed
# laughing
# laughs
# laughter
# laundry
# law
# lawyer
# lay
# lead
# leader
# leaking
# leaky
# lean
# leaned
# learn
# learned
# learning
# least
# leather
# leave
# leaves
# leaving
# lecture
# led
# left
# lefthanded
# leg
# legal
# legend
# legs
# lemon
# lemons
# lend
# length
# lent
# less
# lesson
# lessons
# let
# lets
# letter
# letters
# letting
# levels
# liar
# liars
# library
# license
# licorice
# lid
# lie
# lied
# lies
# life
# lifeboats
# lifes
# lifespan
# lift
# lifted
# light
# lightning
# lights
# like
# liked
# likely
# likes
# limit
# limits
# lincoln
# line
# lines
# linguistics
# lining
# lion
# lips
# list
# listen
# listened
# listener
# listening
# listens
# little
# live
# lived
# lives
# living
# loaf
# loan
# lobby
# local
# located
# lock
# locked
# locking
# lodging
# logarithms
# logo
# london
# lonely
# long
# longer
# longest
# look
# looked
# looking
# looks
# lord
# lose
# loses
# losing
# loss
# lost
# lot
# lots
# loud
# louder
# loudly
# love
# loved
# lovely
# lover
# loves
# loving
# low
# lowbudget
# luck
# luckily
# lucky
# lump
# lumpur
# lunch
# lung
# lying
# machine
# mad
# made
# madrid
# magazine
# magazines
# magnesium
# mahjong
# maid
# mail
# mailbox
# mailing
# main
# maintenance
# major
# majority
# make
# makes
# making
# malaria
# mali
# mammal
# man
# managed
# manager
# manchester
# maniac
# mans
# many
# map
# march
# mark
# market
# marketing
# marriage
# married
# marry
# mars
# mary
# maryam
# marys
# massage
# master
# mastering
# mat
# match
# matches
# math
# mathematics
# matter
# matters
# may
# maybe
# maze
# me
# meadow
# meal
# meals
# mealtime
# mean
# meaning
# meanings
# means
# meant
# measles
# measure
# measured
# meat
# mecca
# medical
# medicine
# medieval
# meet
# meeting
# member
# members
# memorize
# memorizing
# memory
# men
# mention
# merciful
# mercy
# merry
# mess
# message
# messages
# messed
# messengers
# met
# meters
# method
# mexico
# microphone
# microscope
# microwave
# middle
# midjuly
# midjune
# midnight
# might
# mightve
# migrate
# mild
# milder
# mile
# miles
# milk
# million
# mind
# mine
# mineral
# minute
# minutes
# mirror
# miss
# missed
# missing
# mission
# mistake
# mistaken
# mistakenly
# mistakes
# misunderstanding
# misunderstood
# mix
# mobile
# mocked
# mocking
# model
# mom
# moment
# momentous
# mommy
# monastery
# monday
# mondays
# money
# monkey
# monotheistic
# monster
# month
# months
# mood
# moon
# moonlight
# mop
# more
# morning
# mornings
# mortgage
# moscow
# mosque
# mosques
# most
# mother
# mothers
# motorcycle
# mountain
# mountains
# mourning
# mouse
# mouth
# move
# moved
# moves
# movie
# movies
# moving
# mp
# mr
# mt
# muammar
# much
# mud
# mugged
# murder
# murdered
# museum
# museums
# music
# muslim
# muslims
# must
# mustnt
# mustve
# mutual
# my
# myself
# mystery
# mythology
# nail
# naked
# name
# named
# names
# nap
# narrowly
# nation
# national
# nationality
# nations
# native
# natural
# nature
# naughty
# nauseous
# near
# nearby
# nearest
# nearly
# neat
# necessarily
# necessary
# necklace
# necktie
# need
# needed
# needle
# needs
# needy
# negative
# neglect
# neighbor
# neighborhood
# neighbors
# neither
# nerves
# nervewracking
# nervous
# net
# never
# new
# news
# newspaper
# newspapers
# next
# nice
# nick
# night
# nightclub
# nine
# nineties
# no
# nobody
# nobodys
# nodded
# nods
# noise
# noisy
# none
# nonsense
# nonsmokers
# noon
# nor
# normal
# normally
# north
# norway
# nose
# noses
# not
# note
# notebook
# noted
# nothing
# notice
# noticed
# novel
# novelist
# now
# nowadays
# nowhere
# number
# numbers
# nurse
# nutritious
# nuts
# obedient
# obey
# object
# objects
# oblivious
# observant
# observe
# observed
# obvious
# obviously
# occasion
# occasions
# occupation
# occur
# occurred
# occurs
# oclock
# october
# oddly
# of
# off
# offer
# offered
# office
# officer
# offline
# often
# oh
# oil
# ok
# okay
# old
# older
# on
# once
# one
# ones
# onion
# onions
# only
# open
# opened
# opening
# opens
# opera
# opinion
# opinions
# opossum
# opportunity
# opposed
# opposite
# options
# or
# orange
# oranges
# orangutans
# order
# ordered
# orders
# organize
# organized
# origin
# original
# orphan
# osaka
# ostriches
# other
# others
# otherwise
# ottawa
# ought
# our
# ours
# ourselves
# out
# outraged
# outside
# oven
# over
# overcome
# overlook
# overlooking
# overnight
# overseas
# overslept
# owe
# owl
# own
# owns
# oxygen
# oysters
# pacemaker
# pack
# page
# pages
# paid
# pain
# painful
# painted
# painter
# painting
# paintings
# pair
# pale
# pandas
# panicked
# pants
# paper
# papers
# parcel
# pardon
# parent
# parents
# paris
# park
# parked
# parking
# parks
# parrot
# part
# participated
# participation
# parties
# partner
# parts
# party
# pass
# passed
# passengers
# passion
# passport
# password
# passwords
# past
# patient
# patiently
# patients
# pause
# pay
# paying
# peace
# peaceful
# peach
# peanuts
# pearl
# pearls
# peasant
# peel
# pelican
# pen
# pencil
# pencils
# penny
# pens
# people
# peoples
# pepper
# peppers
# perceptive
# perfect
# perform
# performance
# performed
# perhaps
# persian
# person
# personal
# personality
# personally
# persuade
# persuaded
# pet
# pharmacy
# phase
# philip
# philippines
# philosopher
# phone
# phoned
# phones
# photo
# photos
# phrased
# physical
# physics
# pianist
# piano
# picasso
# pick
# picked
# pickpockets
# pickup
# picnic
# picture
# pictures
# pie
# piece
# pieces
# pillow
# pills
# pilot
# pineapple
# pink
# pipes
# pistol
# pit
# pitcher
# pizza
# place
# placed
# plague
# plain
# plan
# plane
# planes
# planet
# planned
# planning
# plans
# planted
# plants
# plastic
# plates
# play
# played
# player
# players
# playing
# plays
# pleasant
# please
# pleased
# pleasure
# pledge
# plenty
# plotting
# plus
# pm
# pneumonia
# pocket
# pocketknife
# poem
# poems
# poet
# poetry
# point
# pointed
# points
# poison
# poisonous
# pole
# police
# policeman
# policemen
# policy
# polish
# polite
# politically
# politics
# pollution
# pond
# ponder
# pool
# pools
# poor
# poorest
# pop
# popular
# popularity
# population
# position
# positive
# possibility
# possible
# possibly
# post
# postpone
# postponed
# pot
# potatoes
# potential
# pound
# pounds
# pour
# poured
# power
# powerful
# powerless
# practical
# practice
# practiced
# practicing
# praise
# pray
# prayed
# precedes
# predictions
# prefer
# preferred
# prefers
# pregnant
# prepare
# prepared
# preparing
# presence
# present
# presents
# preserve
# president
# press
# pressed
# pressure
# pretend
# pretended
# pretending
# prettier
# pretty
# prevent
# prevented
# price
# prices
# prickly
# priest
# prince
# princess
# principal
# principles
# printed
# printing
# prison
# privacy
# private
# privilege
# prize
# probably
# problem
# problems
# problemsolver
# process
# produced
# product
# products
# professional
# profit
# profound
# program
# project
# prolonged
# promise
# promised
# promoted
# promotion
# pronunciation
# proof
# properly
# property
# proposal
# proposed
# protect
# protection
# proud
# prove
# proven
# provided
# pry
# public
# published
# pull
# pulse
# pun
# punished
# punishing
# punishment
# pure
# purpose
# purposes
# purse
# pursuit
# pus
# pushed
# pushups
# put
# puts
# qualified
# quality
# quarrel
# quarter
# queen
# question
# questions
# quick
# quickly
# quiet
# quietly
# quit
# quite
# quote
# quotes
# rabbit
# rabbits
# raccoon
# race
# racket
# radicals
# radio
# railroad
# rain
# rainbow
# rained
# raining
# rains
# rainy
# raise
# raised
# ramadan
# ran
# rang
# ranges
# rap
# rapidly
# rarely
# rate
# rather
# rational
# rats
# ratted
# raw
# reached
# reaction
# read
# reader
# readers
# reading
# reads
# ready
# real
# realize
# realized
# really
# reap
# rear
# reared
# rearended
# rearview
# reason
# rebellious
# recall
# receipt
# receive
# received
# recent
# recently
# recipe
# reciprocated
# recital
# reckon
# recognize
# recognized
# recognizing
# recommend
# recommended
# reconfirm
# reconsider
# record
# recovered
# recovery
# red
# refers
# refreshed
# refrigerator
# refused
# regain
# regained
# regarding
# regards
# registered
# regret
# regularly
# relation
# relationship
# relatively
# relatives
# relativity
# relax
# released
# relief
# relies
# relieve
# religions
# religious
# reluctant
# rely
# relying
# remained
# remains
# remarkable
# remarks
# remember
# remembered
# remembering
# remembers
# remind
# reminded
# reminds
# remote
# remove
# removed
# renew
# rent
# repair
# repaired
# repairs
# repeat
# repeats
# replied
# reply
# report
# representative
# request
# require
# required
# requires
# reread
# rescue
# resembles
# reservation
# reservations
# reserve
# reserved
# resign
# resigned
# resist
# resolve
# resort
# resources
# respect
# respected
# respectful
# responding
# responses
# responsibility
# responsible
# rest
# restaurant
# restaurants
# rested
# restroom
# result
# results
# resume
# retired
# retiring
# return
# returned
# reveal
# revenge
# revolve
# rewrite
# rewrote
# rice
# rich
# richest
# rid
# ride
# rides
# ridiculous
# rifle
# right
# rights
# ring
# ringing
# riot
# rioters
# ripped
# rise
# risen
# rising
# risk
# risks
# risky
# rituals
# river
# road
# roads
# robbed
# robbery
# robinson
# rock
# rocket
# rocks
# rode
# role
# romans
# rome
# roof
# room
# roommates
# rooms
# roosevelt
# rooted
# rose
# roses
# rot
# rotates
# rotten
# rough
# round
# routine
# rude
# rule
# rules
# rumor
# run
# rung
# runner
# running
# runny
# runs
# rushed
# russia
# russian
# ruthless
# s
# sacred
# sad
# safe
# safely
# said
# sailor
# sails
# salad
# salary
# sales
# salesman
# salt
# same
# samples
# san
# sand
# sandwich
# sane
# sang
# santa
# sat
# satisfactory
# satisfied
# satoru
# saturday
# saturdays
# save
# saved
# saving
# savings
# saw
# say
# saying
# says
# scar
# scarcely
# scare
# scared
# scarf
# scary
# scene
# scenery
# schedule
# scheduled
# school
# schools
# science
# scientist
# scientists
# scissors
# scold
# scolded
# score
# scored
# scores
# scotland
# scratched
# screamed
# screams
# sea
# sealed
# search
# season
# seat
# seatbelt
# seats
# seaworthy
# second
# seconds
# secret
# secretary
# section
# see
# seeds
# seeing
# seem
# seemed
# seems
# seen
# sees
# seldom
# selfish
# sell
# selling
# sells
# semester
# send
# senior
# sense
# sensible
# sensing
# sensitive
# sent
# sentence
# sentenced
# sentences
# september
# serious
# seriously
# servant
# servants
# served
# serves
# services
# set
# settle
# settled
# seven
# seventeen
# several
# severe
# severely
# sexy
# shade
# shadow
# shake
# shakespeare
# shall
# shame
# shameful
# shampoo
# shanghai
# shape
# share
# shared
# shark
# sharp
# sharpening
# she
# sheeps
# sheer
# sheets
# shelf
# shell
# shelter
# shes
# shift
# ship
# shipping
# shirt
# shirts
# shock
# shoe
# shoes
# shoot
# shooters
# shop
# shopkeeper
# shopping
# shops
# short
# shortage
# shortcuts
# shorter
# shortly
# shot
# should
# shoulder
# shoulders
# shouldnt
# shouldve
# shout
# shouted
# shouting
# shouts
# show
# showed
# shower
# showered
# showing
# shown
# showroom
# shows
# shuffle
# shut
# shutting
# shy
# siblings
# sick
# sickle
# sickness
# side
# sighed
# sight
# sights
# sign
# signal
# signed
# significant
# signing
# silence
# silent
# silk
# silly
# silver
# similar
# simple
# sin
# since
# sing
# singer
# singing
# single
# sir
# sister
# sisters
# sit
# site
# sitting
# situation
# six
# sixteen
# sixthirty
# sixty
# size
# skate
# ski
# skier
# skies
# skiing
# skill
# skin
# skinny
# skip
# skips
# skirt
# sky
# slacks
# slap
# slapped
# slave
# slaves
# sleep
# sleeping
# sleepy
# slept
# slightly
# slip
# slippers
# slow
# slowly
# sly
# small
# smaller
# smallpox
# smart
# smarter
# smell
# smells
# smile
# smiled
# smiles
# smiling
# smith
# smoke
# smoker
# smoking
# smuggler
# snag
# snails
# snake
# snakes
# sneezing
# snow
# snowed
# snowman
# snows
# so
# soaking
# soap
# soapy
# sober
# soccer
# socialize
# socks
# sofa
# soft
# solar
# sold
# soldier
# soldiers
# solution
# solve
# solved
# solving
# some
# somebody
# someday
# someone
# someplace
# something
# sometimes
# somewhere
# son
# sonata
# song
# sons
# soon
# sooner
# sorrow
# sorrows
# sorry
# sort
# sound
# sounds
# soup
# sour
# source
# sources
# south
# southeastern
# souvenirs
# sow
# space
# spades
# spain
# spanish
# speak
# speaker
# speaking
# speaks
# spear
# special
# specialty
# species
# specific
# spectacular
# speech
# speed
# spend
# spenders
# spending
# spends
# spent
# spicy
# spite
# split
# spoiled
# spoke
# spoken
# spoon
# sport
# sports
# spot
# spots
# spread
# spring
# sprinklers
# spy
# squirrels
# squirt
# squirted
# sretensky
# stage
# stain
# stairs
# stamp
# stamps
# stand
# standards
# standing
# stare
# staring
# stars
# start
# started
# starts
# starve
# starved
# state
# states
# station
# stay
# stayed
# staying
# stays
# steaks
# steal
# stealing
# step
# stepped
# stick
# sticks
# still
# sting
# stock
# stole
# stolen
# stomach
# stomachache
# stone
# stones
# stood
# stop
# stopped
# stopping
# stops
# store
# stores
# stories
# storm
# story
# straight
# strange
# stranger
# strangers
# strategy
# stratfordonavon
# straw
# strawberry
# street
# strengths
# stress
# stressful
# strict
# strike
# strong
# stronger
# strongly
# struck
# struggling
# student
# students
# studied
# studies
# study
# studying
# stuff
# stuffedup
# stupid
# stupidest
# sturdy
# subject
# submerged
# subsaharan
# subtitled
# subway
# succeed
# succeeded
# success
# successful
# such
# sudden
# suddenly
# sue
# suffer
# suffered
# suffering
# sugar
# suggest
# suggested
# suggesting
# suit
# suitable
# suitcase
# suitcases
# suits
# sumatra
# summer
# sun
# sunday
# sundays
# sunglasses
# sunlight
# sunny
# sunrise
# sunscreen
# sunset
# sunshine
# superior
# supper
# support
# supportive
# suppose
# supposed
# suppress
# sure
# surely
# surfboard
# surgery
# surpass
# surprise
# surprised
# surprises
# surprising
# surveillance
# survey
# survive
# survived
# sushi
# suspect
# suspected
# suspended
# suspicious
# swam
# swans
# swear
# sweat
# sweater
# sweden
# sweet
# sweets
# swept
# swim
# swimmer
# swimming
# swims
# swindled
# switch
# switched
# switzerland
# swollen
# sword
# symbolizes
# synchronize
# syria
# syrup
# system
# table
# tackle
# take
# taken
# takes
# taking
# talented
# talents
# tales
# talk
# talkative
# talked
# talking
# talks
# tall
# taller
# tango
# tank
# target
# task
# taste
# tastes
# tatoeba
# tattoo
# taught
# tax
# taxi
# tea
# teach
# teacher
# teachers
# teaches
# teaching
# team
# teams
# tear
# tears
# teasing
# technique
# teenager
# teeth
# telephone
# telescope
# television
# tell
# telling
# tells
# temperature
# temple
# temples
# temporary
# ten
# tenminute
# tennis
# tenth
# terms
# terrible
# terribly
# terrific
# terror
# test
# tests
# texans
# texas
# textbook
# textbooks
# th
# thailand
# than
# thank
# thanked
# thanks
# that
# thatll
# thats
# the
# theater
# theft
# their
# theirs
# them
# themselves
# then
# theory
# there
# theres
# these
# they
# theyll
# theyre
# theyve
# thief
# thin
# thing
# things
# think
# thinking
# thinks
# thins
# thirsty
# thirtieth
# thirty
# this
# those
# though
# thought
# thoughts
# thousand
# threatening
# three
# threebedroom
# threw
# throne
# through
# throughout
# throw
# thrown
# thrust
# thunder
# thursday
# tick
# ticked
# ticket
# tickets
# ticking
# tie
# tied
# tiff
# tight
# tiki
# till
# time
# timeconsuming
# times
# timid
# tip
# tire
# tired
# tires
# to
# today
# todays
# toe
# together
# toilet
# toilets
# tokyo
# told
# tolerant
# tolerate
# tom
# tomatoes
# tomorrow
# tomorrows
# toms
# tone
# tongue
# tonight
# tonights
# too
# took
# toolkit
# tools
# tooth
# toothbrush
# toothpaste
# top
# tore
# tossed
# total
# touch
# touched
# tour
# tourist
# tourists
# toward
# towel
# town
# toy
# toyota
# toys
# trace
# tracks
# trade
# traditionally
# traffic
# train
# trains
# transfer
# translate
# translated
# translation
# translator
# trap
# travel
# traveled
# traveling
# treat
# treated
# treating
# treatment
# treatments
# treats
# treaty
# tree
# trees
# trembled
# tremendously
# trick
# tricky
# tried
# tries
# trip
# tripled
# trips
# trouble
# troubling
# trousers
# trout
# truck
# true
# truer
# truly
# trunk
# trust
# trusted
# trusts
# truth
# try
# trying
# tshirt
# tuesday
# tufts
# tuition
# tune
# turkey
# turkish
# turn
# turned
# turns
# tv
# tvs
# twain
# twelve
# twenties
# twenty
# twice
# two
# twostory
# type
# typhoon
# typical
# typist
# ugliest
# ugly
# ukraine
# ultraviolet
# umbrella
# unacceptable
# unavoidable
# unbelievable
# uncertain
# uncle
# unconscious
# uncover
# under
# underestimate
# underlined
# understand
# understanding
# understands
# understood
# undoubtedly
# undressing
# unexpected
# unfolded
# unfortunately
# unhappy
# unharmed
# unhealthy
# uniforms
# unique
# united
# universal
# university
# universitys
# unknown
# unless
# unlucky
# unpleasant
# unread
# unreliable
# unsure
# until
# unusual
# up
# upon
# upped
# upper
# upsidedown
# upstairs
# uptight
# urgent
# us
# usa
# use
# used
# useful
# useless
# uses
# using
# usual
# usually
# utilized
# vacation
# vaccinated
# valley
# valuable
# value
# various
# vase
# vegetables
# veggies
# vengeance
# venice
# verge
# verse
# verses
# very
# vibrating
# vicinity
# victim
# victory
# video
# videos
# vietnam
# vigilant
# villa
# village
# violence
# violent
# violin
# visa
# visit
# visited
# visiting
# visitors
# vitamin
# voice
# voices
# volleyball
# volume
# volunteer
# vote
# wait
# waited
# waiter
# waiting
# wake
# wakes
# waking
# walk
# walked
# walking
# walks
# wall
# wallet
# wandered
# want
# wanted
# wants
# war
# warcraft
# warm
# warmed
# warmer
# warming
# warn
# warned
# warning
# wars
# was
# wash
# washbasin
# washed
# washing
# washington
# wasnt
# waste
# wasting
# watch
# watched
# watches
# watching
# water
# watered
# watering
# watermelon
# watermelons
# waters
# waved
# waves
# wax
# way
# ways
# we
# weak
# weaknesses
# wealth
# weapons
# wear
# wearing
# wears
# weather
# web
# website
# websites
# wed
# wedding
# wednesday
# week
# weekend
# weeks
# weighing
# weighs
# weight
# weird
# welcome
# well
# wellknown
# went
# wept
# were
# werent
# west
# westerns
# wet
# weve
# whales
# what
# whatd
# whatever
# whatevers
# whatll
# whatre
# whats
# wheat
# wheelchair
# when
# whenever
# where
# wherere
# wheres
# wherever
# whether
# which
# whichever
# while
# whiplash
# whipped
# whiskey
# whistled
# white
# whites
# who
# whoever
# whole
# whore
# whos
# whose
# why
# widow
# widower
# width
# wife
# wifi
# wild
# will
# willing
# win
# wind
# window
# windows
# windy
# wine
# wink
# winning
# winter
# winters
# wiped
# wisdom
# wish
# wished
# wit
# with
# withdraw
# within
# without
# witnessed
# woke
# wolf
# wolves
# woman
# women
# won
# wonder
# wondered
# wonderful
# wondering
# wont
# wood
# word
# words
# wore
# work
# workaholic
# workday
# worked
# worker
# workers
# working
# works
# worksite
# world
# worlds
# worm
# worn
# worried
# worry
# worse
# worship
# worst
# worth
# worthy
# would
# wouldnt
# wouldve
# wound
# wounded
# wraps
# wrist
# write
# writer
# writers
# writes
# writing
# written
# wrong
# wrote
# xrays
# yawned
# yeah
# year
# years
# yeast
# yell
# yelled
# yelling
# yellow
# yen
# yes
# yesterday
# yet
# yoga
# yolks
# york
# you
# youd
# youll
# young
# younger
# your
# youre
# yours
# yourself
# yourselves
# youve
# zero
# zoo

# %%
for i in target_words:
   print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# خيبت
# خيبه
# خير
# دائره
# دائم
# دائما
# داخل
# داخلا
# داخلها
# داخليه
# دار
# داروين
# داعما
# داعمات
# داعي
# دافئ
# دافئا
# دافع
# دافعوا
# دامت
# داوم
# دبلوماسي
# دجاج
# دخل
# دخلت
# دخله
# دراجتك
# دراجته
# دراجتي
# دراجه
# دراسته
# دراسه
# درجات
# درجتك
# درجه
# درس
# درست
# درسني
# درسوا
# دروس
# دع
# دعا
# دعاني
# دعنا
# دعني
# دعه
# دعوت
# دعوتك
# دعوته
# دعونا
# دعوه
# دعوي
# دعيت
# دعينا
# دفئ
# دفتر
# دفترا
# دفتري
# دفع
# دفعت
# دفعته
# دفعه
# دفنت
# دقائق
# دقيق
# دقيقه
# دقيقيه
# دكتورا
# دليل
# دليلا
# دم
# دما
# دمج
# دمر
# دمرت
# دمشق
# دمك
# دمه
# دموعه
# دمي
# دميه
# دهست
# دهسي
# دهنت
# دهني
# دواء
# دور
# دورا
# دورك
# دوري
# دولار
# دولارا
# دولارات
# دوله
# دوما
# دون
# دونت
# دونك
# دونها
# دير
# ديسيمبر
# دين
# ديوننا
# ديونه
# ديوني
# ذئب
# ذا
# ذات
# ذاته
# ذاتها
# ذاك
# ذاكرت
# ذاكرته
# ذاكره
# ذاهب
# ذاهبا
# ذاهبه
# ذاهبون
# ذبلت
# ذراعك
# ذراعه
# ذراعي
# ذروتها
# ذقت
# ذكاءه
# ذكرتني
# ذكرني
# ذكي
# ذكيه
# ذلك
# ذنبي
# ذهابي
# ذهب
# ذهبت
# ذهبنا
# ذهبوا
# ذهنك
# ذودتني
# ذوقيه
# ذيل
# رؤيتك
# رؤيته
# رؤيه
# رئيس
# رئيسا
# رئيسنا
# رئيسه
# رئيسي
# رائحته
# رائحه
# رائد
# رائع
# رائعه
# رات
# راتبه
# راتها
# راجع
# راحتك
# راحه
# راس
# راسك
# راسلت
# راسه
# راسها
# راسي
# راضيا
# راغبا
# راقب
# راكبا
# راكضا
# رامي
# راهبا
# راوني
# راي
# رايت
# رايتك
# رايته
# رايتها
# رايك
# رايكم
# راينا
# رايه
# رب
# ربات
# ربح
# ربحت
# ربحتها
# ربط
# ربطات
# ربطه
# ربما
# رتب
# رتبت
# رج
# رجاء
# رجال
# رجعت
# رجل
# رجلا
# رجلي
# رجليك
# رحلتك
# رحلتكم
# رحلتنا
# رحلتهم
# رحله
# رحمه
# رحيما
# رخصتك
# رخصه
# رخيص
# رخيصا
# رخيصه
# رد
# ردا
# ردت
# رددت
# ردك
# ردهه
# ردي
# رديء
# رزقه
# رزقوا
# رسائل
# رسائلا
# رسالتك
# رسالتها
# رساله
# رسام
# رسب
# رسل
# رسلك
# رسم
# رسمتها
# رسمها
# رسميه
# رسوم
# رش
# رشاوي
# رشح
# رشيق
# رصاص
# رصاصه
# رطلي
# رطلين
# رعاه
# رعبا
# رغب
# رغبته
# رغبتي
# رغبه
# رغم
# رغيف
# رفا
# رفض
# رفضت
# رفع
# رفعت
# رقصتي
# رقم
# ركب
# ركبت
# ركز
# ركزت
# ركض
# ركضا
# ركضت
# ركل
# ركن
# ركوب
# رمضان
# رمي
# رميت
# رن
# رهينتي
# روائيا
# روايته
# روايتها
# روايه
# روبنسون
# روزفلت
# روسيا
# روعك
# روما
# رياضه
# رياضيه
# رياطي
# ريب
# ريثما
# ريح
# زائد
# زائدا
# زاد
# زادت
# زار
# زارت
# زال
# زالت
# زالوا
# زبده
# زبون
# زجاج
# زجاجتي
# زجاجه
# زحام
# زحمه
# زد
# زرت
# زرع
# زرعت
# زرقاء
# زرقاوتان
# زعم
# زعموا
# زفافها
# زفافهم
# زكام
# زلت
# زلزالا
# زملاء
# زملائها
# زملائي
# زمن
# زميلتي
# زهره
# زوار
# زوارق
# زوبعه
# زوج
# زوجا
# زوجت
# زوجتك
# زوجته
# زوجتي
# زوجه
# زوجها
# زوجي
# زياده
# زيارتها
# زيارتهم
# زيارتي
# زياره
# سؤال
# سؤالا
# سؤالك
# سؤاله
# سؤالي
# سئمت
# سائح
# سائحا
# سائحه
# سائق
# سابتاع
# سابدا
# سابذل
# سابقا
# سابقي
# سابقی
# ساتاخر
# ساتارو
# ساتذكرك
# ساترجم
# ساترك
# ساتركك
# ساتزوج
# ساتصل
# ساتواصل
# ساتولي
# ساتي
# ساجد
# ساجعلك
# ساجعلها
# ساجلب
# ساجلبها
# ساحاول
# ساحب
# ساحبك
# ساحبها
# ساحتاج
# ساحصل
# ساحضر
# ساحكي
# ساحول
# ساخبرك
# ساخذ
# ساخذك
# ساخذه
# ساخرج
# ساخفف
# ساخن
# ساخنه
# سادعك
# سادفع
# ساذهب
# سار
# ساراسلك
# سارافقك
# ساراقب
# ساراقبك
# سارسله
# سارفع
# ساره
# ساريك
# سازورك
# سازوره
# ساساعدك
# ساساعده
# ساساله
# ساستحم
# ساسحب
# ساسدد
# ساسعدها
# ساشاهد
# ساشتاق
# ساشتري
# ساشتريه
# ساشرح
# ساشعرها
# ساصبح
# ساطلب
# ساطلبه
# ساطلق
# ساظل
# ساعات
# ساعاتنا
# ساعاود
# ساعترف
# ساعتك
# ساعتني
# ساعتي
# ساعتين
# ساعثر
# ساعد
# ساعدت
# ساعدتني
# ساعدته
# ساعدك
# ساعدنا
# ساعدني
# ساعدوني
# ساعطيك
# ساعلمك
# ساعمل
# ساعه
# ساعود
# ساعيرك
# ساعيش
# ساغادر
# ساغسل
# ساغيب
# ساغير
# سافتقد
# سافتقدك
# سافتقدكم
# سافر
# سافرت
# سافعل
# سافعله
# سافعلها
# سافكر
# ساقابلك
# ساقاضيك
# ساقرا
# ساقرر
# ساقرضك
# ساقلك
# ساقه
# ساقول
# ساقوله
# ساقوم
# ساقيس
# ساكل
# ساكنا
# ساكون
# سال
# سالت
# سالتني
# سالته
# سالعب
# سالقي
# سالني
# سامحني
# سامر
# ساملك
# سامه
# سامي
# سان
# سانتظر
# سانتظرك
# سانتقل
# ساندويشا
# سانزل
# سانسي
# سانصحك
# سانضم
# سانهي
# ساوافيك
# ساوبخه
# ساوصلك
# سباحه
# سبب
# سببت
# سببته
# سببه
# سبتمبر
# سبعه
# سبق
# سبورت
# سبيل
# ست
# ستاتي
# ستاخذ
# ستاخذك
# ستاخذون
# ستاكل
# ستاكلون
# ستبحر
# ستبدا
# ستبقي
# ستبيع
# ستبيعه
# ستتاخر
# ستتحسن
# ستتزوج
# ستتصل
# ستتعلم
# ستتفاجئ
# ستثلج
# ستجد
# ستجعل
# ستحبه
# ستحتاج
# ستحضر
# ستذهب
# ستراتفورد
# سترته
# سترجع
# ستره
# ستري
# ستساعدني
# ستساعده
# ستستمر
# ستشعر
# ستشكك
# ستصنع
# ستضل
# ستضيع
# ستعترف
# ستعود
# ستغادر
# ستغني
# ستفاجا
# ستفعل
# ستفعله
# ستفعلين
# ستفهم
# ستفوت
# ستقرر
# ستقلع
# ستقول
# ستقولين
# ستقوم
# ستقومين
# ستكون
# ستلتقي
# ستلعب
# ستمطر
# ستناقش
# ستنبهر
# ستنجح
# ستنجزه
# ستنساني
# ستنسني
# ستنسي
# ستنشر
# ستنطلق
# سته
# ستوافق
# ستوصلك
# ستون
# سجل
# سجلت
# سحبتها
# سخر
# سخيف
# سخيفا
# سد
# سددت
# سديده
# سدی
# سر
# سرا
# سرتينسكي
# سررت
# سرطان
# سرعته
# سرعه
# سرق
# سرقت
# سرقتها
# سرقه
# سرير
# سريرك
# سريري
# سريع
# سريعا
# سريعه
# سريعي
# سطح
# سعال
# سعداء
# سعر
# سعرات
# سعره
# سعه
# سعيد
# سعيدا
# سعيداانت
# سعيده
# سعيدهساسعدك
# سعيدون
# سفرك
# سفري
# سفيرا
# سفيره
# سفينه
# سقط
# سقطت
# سقف
# سقوط
# سقوطها
# سقي
# سكاري
# سكان
# سكاي
# سكبت
# سكر
# سكران
# سكرانه
# سكرت
# سكرتيره
# سكنا
# سكنيه
# سكون
# سكين
# سكينا
# سكينك
# سلاحك
# سلام
# سلامي
# سلب
# سلبيا
# سلطته
# سلم
# سلمت
# سلمون
# سله
# سلوك
# سليما
# سم
# سماع
# سماعك
# سماعكم
# سماعه
# سماعي
# سمح
# سمحت
# سمع
# سمعت
# سمعتكما
# سمعته
# سمك
# سمكه
# سمنت
# سميت
# سميث
# سمين
# سمينا
# سن
# سنا
# سناكل
# سنتاخر
# سنتبعك
# سنتحدث
# سنتين
# سنجد
# سنحتاج
# سنحمي
# سندفع
# سنذهب
# سنرغب
# سنري
# سنسافر
# سنسال
# سنستطيع
# سنستمر
# سنسدد
# سنعرف
# سنعيش
# سنفتقد
# سنفعل
# سنقتلك
# سنقوم
# سنقيم
# سنكتفي
# سنلتقي
# سنلحق
# سنلعب
# سننتظر
# سنه
# سنوات
# سنويا
# سني
# سنين
# سهر
# سهل
# سهلا
# سهله
# سوء
# سوءا
# سواء
# سواءا
# سوداء
# سوداني
# سوريا
# سوف
# سوق
# سوناته
# سوي
# سويا
# سويسرا
# سويه
# سوی
# سي
# سيء
# سيئ
# سيئا
# سيئه
# سياتي
# سياج
# سياجا
# سياح
# سياحه
# سياحي
# سياحيه
# سياخذ
# سياخذك
# سيارات
# سيارتان
# سيارتك
# سيارتنا
# سيارته
# سيارتها
# سيارتي
# سيارتين
# سياره
# سياسه
# سياسيه
# سيبدا
# سيبقون
# سيبقي
# سيبيع
# سيتخرج
# سيتزوج
# سيتزوجا
# سيتساقط
# سيتصل
# سيتغير
# سيتقاعد
# سيتم
# سيتمكن
# سيجاره
# سيجري
# سيحدث
# سيحصل
# سيحضر
# سيخبرنا
# سيخبرني
# سيختتم
# سيخفف
# سيداتي
# سيدفع
# سيدفعون
# سيده
# سيدي
# سيذهب
# سير
# سيرا
# سيرتي
# سيرغب
# سيروق
# سيزور
# سيساعدني
# سيسافر
# سيستغرق
# سيسدد
# سيسددون
# سيسعدني
# سيسيرعلي
# سيصبح
# سيصدر
# سيصل
# سيصلوا
# سيصيبك
# سيصير
# سيضربون
# سيضطر
# سيطره
# سيطلي
# سيطول
# سيظلون
# سيعتني
# سيعود
# سيغادر
# سيغضب
# سيغلق
# سيغير
# سيفرج
# سيفشل
# سيفعل
# سيفعلها
# سيفوتك
# سيفي
# سيقام
# سيقبل
# سيقتلني
# سيقدر
# سيقلك
# سيقيمون
# سيكتب
# سيكذب
# سيكلف
# سيكلفك
# سيكون
# سينتهي
# سينطلق
# سينيه
# سيهرب
# سيهطل
# سيوظف
# شئ
# شئت
# شائعه
# شاب
# شابا
# شاحب
# شاحبا
# شاحنه
# شارع
# شارفت
# شارك
# شاركتنا
# شاركوا
# شاعرا
# شاقا
# شاكر
# شان
# شانغهاي
# شانك
# شانكاهاي
# شاهد
# شاهدت
# شاهدتم
# شاهدته
# شاهدنا
# شاي
# شايا
# شب
# شبابه
# شبحا
# شبعان
# شبعت
# شبهه
# شبيهه
# شتاء
# شتم
# شتمني
# شجاع
# شجاعا
# شجاعتك
# شجاعته
# شجره
# شحن
# شخص
# شخصا
# شخصي
# شخصيا
# شخصيته
# شخصيتها
# شخصيتي
# شده
# شديد
# شديده
# شر
# شراء
# شراءه
# شرائح
# شراب
# شرابا
# شرابك
# شرب
# شربا
# شربت
# شرح
# شرحه
# شرط
# شرطيا
# شركتك
# شركتنا
# شركه
# شروطكم
# شروق
# شريرا
# شريفه
# شريكك
# شزرا
# شطائر
# شعبي
# شعبيه
# شعر
# شعرا
# شعرت
# شعرك
# شعرنا
# شعره
# شعرها
# شعري
# شعورا
# شعوران
# شعورها
# شفه
# شقراوتان
# شقه
# شقوا
# شك
# شكر
# شكرا
# شكرك
# شكرني
# شكري
# شكسبير
# شكك
# شكل
# شكله
# شكلها
# شمسيه
# شنيعا
# شهد
# شهدنا
# شهر
# شهرا
# شهره
# شهرين
# شهور
# شهيا
# شهير
# شهيه
# شوكه
# شيء
# شيئ
# شيئا
# شيئان
# شيئين
# شيد
# شيقا
# شيقه
# صائب
# صابره
# صابون
# صاح
# صاحبه
# صاخبه
# صادفت
# صادق
# صادقين
# صارم
# صارما
# صاروا
# صاغيه
# صافيه
# صالح
# صالحا
# صالحه
# صامتا
# صامتين
# صباح
# صباحا
# صبت
# صبرا
# صبغ
# صبور
# صبورا
# صبيا
# صبيه
# صحبتها
# صحتك
# صحتي
# صحح
# صححت
# صححني
# صحه
# صحوا
# صحي
# صحيح
# صحيحا
# صحيحه
# صداع
# صداعك
# صداقتك
# صداقتنا
# صداقتهم
# صدبقتك
# صدري
# صدق
# صدقك
# صدقه
# صدقوا
# صدم
# صدمت
# صدمته
# صدمه
# صديق
# صديقا
# صديقان
# صديقتك
# صديقتي
# صديقك
# صديقنا
# صديقه
# صديقها
# صديقي
# صديقين
# صراخا
# صراف
# صرت
# صرخ
# صرخت
# صرخه
# صرخوا
# صرصار
# صرف
# صريحه
# صعب
# صعبا
# صعبه
# صعد
# صعدت
# صعوبه
# صغارا
# صغري
# صغير
# صغيرا
# صغيره
# صف
# صفاته
# صفار
# صفحات
# صفحتي
# صفحه
# صفر
# صفراء
# صفعت
# صفعته
# صفق
# صفقه
# صفك
# صفنا
# صفوه
# صفي
# صلاحيه
# صلب
# صلبه
# صلصه
# صله
# صليت
# صمام
# صمم
# صناعه
# صناعي
# صناعيه
# صنبور
# صندوق
# صنع
# صنعت
# صنعتها
# صواب
# صوب
# صوبت
# صوت
# صوتا
# صوتك
# صوتها
# صور
# صورتان
# صورك
# صوره
# صومطره
# صياغتها
# صيد
# صيدليه
# صيني
# صينيا
# ضئيله
# ضاحكا
# ضارب
# ضاره
# ضاعت
# ضجرا
# ضجه
# ضحك
# ضحكت
# ضحكتي
# ضخم
# ضخما
# ضخمه
# ضد
# ضدنا
# ضرب
# ضربه
# ضرر
# ضررا
# ضروري
# ضروريا
# ضروريه
# ضع
# ضعف
# ضعه
# ضعها
# ضعيفا
# ضعيفه
# ضغط
# ضلت
# ضمت
# ضميرك
# ضميري
# ضوء
# ضيف
# ضيوف
# ضيوفك
# طائرات
# طائرتك
# طائرتنا
# طائرتي
# طابع
# طابعا
# طابعه
# طابق
# طابقين
# طابه
# طارئ
# طارئه
# طازجا
# طاعن
# طاقتي
# طالب
# طالبا
# طالبه
# طالبوا
# طالبين
# طالعها
# طاولتي
# طاوله
# طباخ
# طباخه
# طبخك
# طبع
# طبعا
# طبقا
# طبقين
# طبيب
# طبيبا
# طبيبك
# طبيبه
# طبيبي
# طبيعته
# طبيعتها
# طبيعه
# طبيعي
# طبيعيه
# طبيه
# طرح
# طرد
# طرده
# طرق
# طريفا
# طريق
# طريقك
# طريقنا
# طريقه
# طريقها
# طريقهم
# طريقي
# طريقي‏‏
# طعام
# طعاما
# طعامك
# طعامه
# طعم
# طعمت
# طعمه
# طعمها
# طفل
# طفلا
# طفلك
# طفله
# طفولتك
# طفولته
# طفولتي
# طفوله
# طفيف
# طقس
# طقم
# طلاب
# طلابك
# طلابه
# طلب
# طلبت
# طلبته
# طلبك
# طلبناه
# طلبه
# طلبها
# طلبوا
# طلبي
# طلت
# طلتك
# طلقت
# طلي
# طلينا
# طمع
# طموحه
# طموحها
# طهو
# طهيت
# طوابع
# طوابق
# طوارئ
# طوال
# طور
# طوكيو
# طول
# طولا
# طولك
# طوله
# طولي
# طوم
# طويل
# طويلا
# طويله
# طي
# طيارا
# طيب
# طيبه
# طيله
# ظروف
# ظل
# ظلت
# ظلها
# ظن
# ظنت
# ظنك
# ظننت
# ظننتك
# ظننتني
# ظننته
# ظنني
# ظني
# ظهر
# ظهرا
# ظهرت
# ظهره
# ظهري
# ظهيره
# عائلتك
# عائلتنا
# عائلته
# عائلتي
# عائله
# عاجزا
# عاجلا
# عاد
# عاداته
# عادت
# عادتنا
# عادته
# عادتها
# عادل
# عادلا
# عاده
# عادي
# عار
# عاريا
# عازبا
# عازبه
# عازف
# عازفي
# عاش
# عاشوا
# عاصف
# عاصفه
# عاصمه
# عاطل
# عاقلا
# عاك
# عال
# عالم
# عالما
# عالمي
# عالميه
# عاليا
# عاليه
# عام
# عاما
# عامل
# عاملا
# عاملتها
# عاملني
# عامي
# عامين
# عاني
# عاهدت
# عبثت
# عبدك
# عبر
# عبرت
# عبقري
# عبور
# عثر
# عثرت
# عجرفته
# عجله
# عجوز
# عجوزا
# عد
# عدا
# عدت
# عدد
# عددا
# عدلا
# عدم
# عدمه
# عدنا
# عدني
# عده
# عدوك
# عدونا
# عدي
# عديده
# عديم
# عذر
# عذرا
# عرب
# عربات
# عرسهما
# عرض
# عرضت
# عرضك
# عرضه
# عرضي
# عرف
# عرفت
# عرفته
# عرفتهم
# عرفنا
# عرفني
# عرفه
# عرق
# عزاء
# عزف
# عزفت
# عزم
# عساني
# عشاؤنا
# عشائك
# عشائي
# عشت
# عشتها
# عشر
# عشره
# عشرون
# عشرين
# عصافير
# عصر
# عصفور
# عصفورا
# عصي
# عصيت
# عصير
# عصيرا
# عض
# عضو
# عضوا
# عضوي
# عطش
# عطشا
# عطشان
# عطشانا
# عطلتك
# عطله
# عظام
# عظيم
# عظيما
# عفن
# عفوا
# عقابهم
# عقب
# عقد
# عقدت
# عقرب
# عقله
# عكس
# علاج
# علاقتهما
# علاقه
# علام
# علامه
# علق
# علقت
# علم
# علمت
# علمتني
# علمتي
# علمنا
# علمني
# علمي
# علومك
# علي
# عليتك
# عليك
# عليكم
# عليلا
# علينا
# عليه
# عليها
# عليهم
# علی
# عم
# عما
# عمال
# عمتك
# عمتي
# عمدا
# عمر
# عمرا
# عمرك
# عمرنا
# عمره
# عمرها
# عمري
# عمك
# عمل
# عملا
# عملت
# عملته
# عملك
# عملنا
# عمله
# عملها
# عملي
# عمليه
# عمن
# عمه
# عموما
# عمي
# عميقه
# عن
# عناق
# عند
# عندك
# عندما
# عندنا
# عنده
# عندها
# عندهم
# عندي
# عنصر
# عنق
# عنقك
# عنقي
# عنك
# عننا
# عنه
# عنها
# عنوان
# عنوانا
# عنوانك
# عنوانه
# عنوانها
# عنواني
# عني
# عنيفه
# عوامل
# عود
# عودك
# عودوا
# عوضا
# عوقب
# عوقبوا
# عيادته
# عياده
# عيد
# عيسي
# عيشه
# عينا
# عيناك
# عينان
# عيناه
# عيناها
# عيناي
# عينه
# عيني
# عينيك
# عينيه
# عيونها
# غائب
# غائبا
# غائبان
# غائبه
# غاب
# غابت
# غادر
# غادرت
# غادرنا
# غادروا
# غارق
# غاضب
# غاضبا
# غاضبات
# غاضبه
# غاضبين
# غال
# غالبا
# غالي
# غاليا
# غاليه
# غامق
# غايتي
# غايه
# غباء
# غبار
# غبي
# غبيا
# غد
# غدا
# غذائي
# غذائيه
# غرب
# غربا
# غردت
# غرف
# غرفا
# غرفتك
# غرفته
# غرفتها
# غرفتهم
# غرفتي
# غرفه
# غرق
# غروب
# غريب
# غريبا
# غريبه
# غزي
# غسل
# غسلت
# غضب
# غضبا
# غضبان
# غضبه
# غضبهم
# غضبهن
# غضون
# غطاء
# غطاه
# غطست
# غفوت
# غلطتي
# غمز
# غمس
# غمست
# غمسته
# غناء
# غناءها
# غناك
# غنت
# غني
# غنيا
# غنيه
# غواكامولي
# غيابي
# غير
# غيرت
# غيرك
# غيظ
# غيوم
# فئه
# فائده
# فائق
# فاتتك
# فاتتني
# فاتته
# فاتح
# فاتك
# فاتن
# فاتنا
# فاته
# فاتوره
# فاجا
# فاجات
# فاجانا
# فاحالها
# فادحه
# فارا
# فاردت
# فارغ
# فارغه
# فاز
# فاسدا
# فاصل
# فاصمت
# فاطلب
# فاعترف
# فاعلا
# فاعمل
# فاقده
# فاكهه
# فالسكوت
# فالمهم
# فالنتفق
# فان
# فانا
# فانت
# فانك
# فانكسر
# فانني
# فانه
# فاني
# فاي
# فايرفوكس
# فبامكانك
# فبراير
# فتاه
# فتح
# فتحت
# فترتين
# فتره
# فتش
# فتعال
# فجاه
# فحسب
# فحص
# فحصوا
# فخلدت
# فخور
# فخوران
# فخوره
# فراشه
# فراغك
# فراغي
# فرانسيسكو
# فراوله
# فرحا
# فرحت
# فرحه
# فرش
# فرشاه
# فرصتنا
# فرصه
# فرضك
# فرق
# فرقتنا
# فرنسا
# فرنسي
# فرنسيا
# فرنسيه
# فروضك
# فروضي
# فريق
# فريقا
# فريقنا
# فزت
# فزنا
# فساساعدك
# فساعيرك
# فسانسي
# فستان
# فستانا
# فستانك
# فسنصل
# فسنعدك
# فسنكون
# فسيكون
# فشكك
# فشل
# فشلت
# فشلنا
# فصاعدا
# فصل
# فصلك
# فصلنا
# فصلي
# فصول
# فضاء
# فضلا
# فضلت
# فضلك
# فضه
# فطلب
# فطيره
# فظيع
# فظيعا
# فظيعه
# فعل
# فعلا
# فعلت
# فعلته
# فعلتها
# فعلتيه
# فعلك
# فعله
# فعلها
# فعلي
# فعليهم
# فقتل
# فقد
# فقدت
# فقدوا
# فقررنا
# فقره
# فقط
# فقله
# فقير
# فقيرا
# فكر
# فكرتي
# فكرتين
# فكره
# فلا
# فلسا
# فلفلا
# فلم
# فلما
# فلن
# فلنبدا
# فلنركب
# فلنسالها
# فلنغلق
# فلننتظر
# فلورنس
# فلوريدا
# فم
# فما
# فماذا
# فمك
# فمه
# فنان
# فناني
# فنجان
# فنجانا
# فندق
# فني
# فهرب
# فهم
# فهمت
# فهمته
# فهمتها
# فهمني
# فهمها
# فهموا
# فهو
# فوائد
# فوات
# فواتير
# فوت
# فوتت
# فوجي
# فورد
# فوزه
# فوطه
# فوق
# فول
# في
# فيتنام
# فيجب
# فيك
# فيلسوف
# فيلم
# فيليب
# فيم
# فيما
# فينا
# فينس
# فيه
# فيها
# قائد
# قائدكم
# قائمتنا
# قائمه
# قابلت
# قابلته
# قابلتها
# قابلنا
# قابلني
# قاتل
# قاتلوا
# قاد
# قادر
# قادرا
# قادره
# قادم
# قادمه
# قارئ
# قاربت
# قارس
# قاروره
# قاس
# قاست
# قاسي
# قاسيا
# قاسيه
# قاطعا
# قاطعته
# قال
# قالت
# قالته
# قاله
# قام
# قامت
# قامه
# قاموا
# قاموس
# قاموسا
# قاموسك
# قاموسي
# قانوني
# قايض
# قبرك
# قبره
# قبض
# قبطان
# قبعتك
# قبعتها
# قبعتي
# قبعه
# قبل
# قبلا
# قبلت
# قبله
# قبلها
# قبول
# قبوله
# قبيح
# قتل
# قتلت
# قتلنا
# قتلها
# قتلي
# قد
# قدامي
# قدد
# قدر
# قدرتك
# قدرته
# قدرتي
# قدرنا
# قدم
# قدما
# قدماي
# قدمت
# قدمه
# قدمي
# قدميه
# قدوم
# قدومك
# قديم
# قديمه
# قذفت
# قرا
# قراءته
# قراءتهم
# قراءه
# قراءها
# قرابه
# قرات
# قراتها
# قرار
# قرارا
# قراراتي
# قرارك
# قرارهم
# قراري
# قرب
# قربي
# قرده
# قرر
# قررا
# قررت
# قره
# قريب
# قريبا
# قريبه
# قريه
# قزح
# قسط
# قسطا
# قسم
# قسمت
# قسمه
# قش
# قصاري
# قصته
# قصتها
# قصد
# قصدت
# قصدك
# قصدي
# قصص
# قصف
# قصفت
# قصه
# قصها
# قصيده
# قصيره
# قضاء
# قضائيه
# قضي
# قضيت
# قضينا
# قضيه
# قط
# قطار
# قطارا
# قطاع
# قطب
# قطتك
# قطتي
# قطره
# قطع
# قطعا
# قطعت
# قطعه
# قطعي
# قطن
# قطه
# قطي
# قعدنا
# قف
# قفازات
# قفازاتي
# قفازيه
# قفازيها
# قفز
# قفوا
# قل
# قلب
# قلبك
# قلبه
# قلبها
# قلبي
# قلبيه
# قلت
# قلته
# قلعه
# قلق
# قلقا
# قلقلنا
# قلقه
# قلم
# قلما
# قلمك
# قلمه
# قلمها
# قلمي
# قله
# قلها
# قلوب
# قليل
# قليلا
# قليله
# قم
# قماش
# قمت
# قمصانه
# قمنا
# قمه
# قميصا
# قميصك
# قنبله
# قنينه
# قهوتك
# قهوته
# قهوه
# قواعدي
# قواميسك
# قوانين
# قوتك
# قوس
# قول
# قوله
# قوم
# قوموا
# قوه
# قوي
# قويا
# قويه
# قيادتها
# قيادتي
# قياده
# قياسك
# قيثاره
# قيد
# قيل
# قيلوله
# قيما
# قيمته
# كؤوس
# كئيبا
# كاتبا
# كاثوليكي
# كاد
# كادت
# كاذب
# كارثه
# كارنب
# كارويزاوا
# كاس
# كاسا
# كاف
# كافر
# كافيا
# كافيار
# كافيه
# كالاحمق
# كالارنب
# كالاطفال
# كالثعلب
# كالثلج
# كالجديده
# كالحصان
# كالحلم
# كالدجاجه
# كالصخر
# كالمسمار
# كالهدايا
# كالورده
# كاليفورنيا
# كامك
# كامل
# كاملا
# كامله
# كاميرا
# كاميرات
# كاميرتي
# كان
# كانا
# كانت
# كانك
# كاننا
# كانه
# كانها
# كانهم
# كانو
# كانوا
# كاهلها
# كاوساكا
# كاي
# كبار
# كبرت
# كبوه
# كبير
# كبيرا
# كبيره
# كتاب
# كتابا
# كتابك
# كتابه
# كتابها
# كتابي
# كتابين
# كتب
# كتبا
# كتبت
# كتبك
# كتبنا
# كتبه
# كتبها
# كتبهم
# كتبي
# كتفاحه
# كتفه
# كتفي
# كتلك
# كتن
# كتوم
# كثب
# كثر
# كثير
# كثيرا
# كثيره
# كثيرون
# كثيرين
# كحه
# كذاك
# كذب
# كذبت
# كذبه
# كذلك
# كرد
# كررت
# كرس
# كرست
# كرسي
# كرسيا
# كرسيك
# كره
# كرهت
# كرهته
# كرواتيا
# كرويه
# كريم
# كريمه
# كريه
# كسائح
# كسر
# كسرت
# كسره
# كسرها
# كسكين
# كشف
# كشفت
# كصباح
# كطفل
# كعكتك
# كعكه
# كعلم
# كعيني
# كف
# كفا
# كفاك
# كفايتك
# كفايه
# كفي
# كل
# كلا
# كلابتون
# كلابك
# كلاكما
# كلام
# كلامك
# كلانا
# كلاهما
# كلب
# كلبا
# كلبك
# كلبنا
# كلبه
# كلبي
# كلبين
# كلتا
# كلف
# كلفت
# كلفتك
# كلكم
# كلما
# كلمات
# كلمت
# كلمتني
# كلمني
# كلمه
# كلنا
# كله
# كلها
# كلهم
# كلي
# كليا
# كليه
# كم
# كما
# كمان
# كمانا
# كمبيوتر
# كمجموعات
# كمرته
# كمرشد
# كمقبل
# كممثل
# كمن
# كميه
# كن
# كنا
# كنت
# كنتم
# كندا
# كنديون
# كنس
# كنغرا
# كنيسه
# كهذا
# كوالالمبور
# كوب
# كوبا
# كوت
# كوجهه
# كوريا
# كوكب
# كوكبنا
# كولومبيا
# كومه
# كونج
# كونه
# كونها
# كونوا
# كوني
# كي
# كيس
# كيسها
# كيف
# كيفيه
# كيلو
# كيلومترات
# كيلي
# كيميائي
# كينيا
# كيوتو
# لؤلؤ
# لئلا
# لا
# لابد
# لابقائهم
# لابنه
# لابني
# لابي
# لاتتاخر
# لاتخذ
# لاتذكرها
# لاترجم
# لاتصل
# لاتمشي
# لاجازه
# لاجتهادك
# لاجعلك
# لاجل
# لاجلك
# لاجلكلك
# لاجله
# لاجلي
# لاحافظ
# لاحتساء
# لاحد
# لاحذ
# لاحصل
# لاحظ
# لاحظت
# لاحقا
# لاخبارنا
# لاخباره
# لاختك
# لاخذ
# لاخذت
# لاخذي
# لاخر
# لاخفائه
# لاخي
# لادرس
# لاراك
# لاري
# لاريك
# لازالت
# لازلت
# لاسالك
# لاستخدام
# لاستراليا
# لاستضافتك
# لاسنانك
# لاشرب
# لاشعه
# لاشيء
# لاصوت
# لاطباء
# لاطلب
# لاعب
# لاعبون
# لاعبي
# لاعطيك
# لاعطيه
# لاعمل
# لاغراض
# لافعل
# لافعله
# لافعلها
# لاقتراحي
# لاقرا
# لاقراها
# لاقطع
# لاقناع
# لاقود
# لاكثر
# لاكل
# لاكله
# لامري
# لامي
# لان
# لانجز
# لانجزه
# لانسي
# لانقاذك
# لانقاذها
# لانك
# لانني
# لانه
# لانها
# لانهائيه
# لانهي
# لاني
# لاهله
# لاي
# لايبدو
# لبثت
# لبرنامجك
# لبست
# لبضع
# لبضعه
# لبعض
# لبعضه
# لبعضهم
# لبقيه
# لبوستن
# لتاخذنا
# لتترجم
# لتتمشي
# لتحذيري
# لتحصل
# لتحل
# لتدرس
# لتدريس
# لتراني
# لترك
# لتساعدنا
# لتسال
# لتسديد
# لتسويه
# لتشجيع
# لتشرب
# لتشربه
# لتصديق
# لتصلح
# لتعلم
# لتفضل
# لتفعل
# لتفعله
# لتفعليه
# لتقرر
# لتقول
# لتكون
# لتناول
# لتنمو
# لتوم
# لتوي
# لثتك
# لثلاث
# لثلاثه
# لجدته
# لجلب
# لجمع
# لحاجه
# لحساب
# لحسن
# لحضور
# لحظات
# لحظه
# لحفله
# لحق
# لحقت
# لحل
# لحله
# لحم
# لحما
# لحمايتك
# لحن
# لحنا
# لحوم
# لخدمه
# لخطه
# لخمس
# لدرجه
# لدعمهم
# لدعوتك
# لدعوه
# لدقيقه
# لدي
# لديك
# لديكم
# لدينا
# لديه
# لديها
# لديهم
# لديهما
# لذا
# لذاك
# لذلك
# لذهبت
# لذيذ
# لذيذه
# لرؤيتك
# لرؤيتي
# لرؤيه
# لربما
# لرحله
# لرمز
# لزوجته
# لزيارتنا
# لزيارتي
# لزياره
# لسؤالك
# لساعات
# لساعتين
# لساعه
# لساني
# لسبب
# لست
# لسرقه
# لسماع
# لسنا
# لسنوات
# لسوء
# لشخص
# لشخصين
# لشراء
# لشرب
# لشرح
# لشرحك
# لشركتنا
# لشكسبير
# لشهر
# لشيكسبير
# لصالح
# لصحتك
# لصديقها
# لصديقي
# لضربات
# لضيفه
# لطالما
# لطف
# لطفا
# لطفك
# لطفل
# لطفلتك
# لطفلها
# لطفها
# لطيف
# لطيفا
# لطيفه
# لعامين
# لعب
# لعبت
# لعبتي
# لعبنا
# لعبه
# لعجلتي
# لعدم
# لعده
# لعطله
# لعل
# لعلك
# لعلنا
# لعله
# لعمل
# لعملي
# لعيد
# لغات
# لغتك
# لغته
# لغتها
# لغتهم
# لغتي
# لغرفتي
# لغزا
# لغه
# لفت
# لفتت
# لفتره
# لفشل
# لفشلت
# لفعل
# لفعلت
# لفعله
# لفقرك
# لفكره
# لقاح
# لقتل
# لقد
# لقدطلب
# لقدومك
# لقراءه
# لقرابه
# لقضاء
# لقطار
# لقلم
# لقمه
# لقواعد
# لقول
# لقوله
# لقيادته
# لقياس
# لقيامه
# لك
# لكان
# لكرسي
# لكسب
# لكل
# لكم
# لكن
# لكنت
# لكنك
# لكننا
# لكنني
# لكنه
# لكنها
# لكنهم
# لكني
# لكي
# للابحار
# للابد
# للاتحاد
# للاجهاد
# للاحراج
# للاختباء
# للاختلاط
# للارانب
# للاسبوع
# للاستعجال
# للاسف
# للاسوا
# للاصدقاء
# للاطفال
# للاعتذار
# للاعتقاد
# للاعصاب
# للاكل
# للامتحان
# للامر
# للانتظار
# للانجليزيه
# للانسان
# للاهتمام
# للبجعه
# للبحث
# للبحيره
# للبدء
# للبشر
# للبيت
# للتحدث
# للتحقق
# للتحليه
# للتخلي
# للتخيم
# للتذاكر
# للتذكر
# للتذكره
# للتسوق
# للتصويت
# للتنس
# للتو
# للتوتر
# للتوقف
# للجري
# للجلوس
# للجميع
# للجهه
# للحاسوب
# للحديث
# للحزر
# للحصبه
# للحظه
# للحفله
# للحكومه
# للحلوي
# للخارج
# للخطه
# للخوف
# للدراجه
# للدراسه
# للدستور
# للدفاع
# للذهاب
# للراحه
# للربح
# للرجل
# للرحيل
# للرقص
# للروعه
# للسباحه
# للسلطه
# للسياح
# للسينما
# للشرب
# للشرطه
# للشركه
# للشك
# للشيوعيه
# للصحه
# للصيانه
# للصيد
# للطائرات
# للطابق
# للطاقه
# للطف
# للطيران
# للعاده
# للعالم
# للعب
# للعثور
# للعشاء
# للعقد
# للعمل
# للعيش
# للغات
# للغايه
# للغداء
# للغه
# للفخر
# للفراش
# للفرنسيه
# للفوز
# للقدوم
# للقطارات
# للقهوه
# للقيام
# للكاميرا
# للكبار
# للكتابه
# للكلاب
# للكلب
# للكوالا
# للمبتدئين
# للمتابعه
# للمتجر
# للمدرسه
# للمدينه
# للمراه
# للمزيد
# للمساعده
# للمستشفي
# للمطار
# للمعالجه
# للمغادره
# للمفاتيح
# للمكتبه
# للممثله
# للمنزل
# للموسيقا
# للميلاد
# للنادل
# للنسيان
# للنشيد
# للنعام
# للنوم
# لله
# للهروب
# للهيدروجين
# للوجبه
# للوصول
# للوظيفه
# للوقت
# للوقود
# لليابان
# لليوم
# لم
# لمؤسسه
# لما
# لماذا
# لماري
# لمجهوداته
# لمجيئك
# لمحتها
# لمده
# لمذا
# لمركز
# لمره
# لمزيد
# لمساعدتك
# لمساعدتهم
# لمساعدتي
# لمساعده
# لمسافه
# لمشاهده
# لمعرفه
# لمفتاحي
# لمقابلتك
# لمن
# لمنتجاتكم
# لمنزلي
# لمهمتنا
# لموت
# لميري
# لن
# لنا
# لناخذ
# لناكل
# لنامل
# لنبدا
# لنتحدث
# لنتحدع
# لنتصافح
# لنتقابل
# لنتوقف
# لنجاحنا
# لنجاحه
# لنجرب
# لنجلس
# لنحتفل
# لندع
# لندن
# لنذهب
# لنرجع
# لنري
# لنساعد
# لنسرع
# لنسكر
# لنسمع
# لنسيانك
# لنشاهد
# لنشرب
# لنصيحتي
# لنضبط
# لنعد
# لنعمل
# لنغني
# لنفسك
# لنفسه
# لنفسها
# لنفكر
# لنقاش
# لنقب
# لنكن
# لنكولن
# لنلتقي
# لنلعب
# لنلق
# لنناقش
# لننتظر
# لننس
# لننسي
# لنواجه
# له
# لهؤلاء
# لها
# لهذا
# لهذه
# لهم
# لهنا
# لو
# لوجه
# لوجود
# لوح
# لوحات
# لوحتك
# لوحدك
# لوحده
# لوحدها
# لوحدي
# لوحظت
# لوحه
# لوظيفتي
# لوقاحتك
# لوقت
# لولا
# لوم
# لون
# لونه
# لونها
# لوني
# لي
# لياقتي
# لياكله
# ليبقوا
# ليتعلم
# ليتني
# ليتواجد
# ليجرب
# ليحميك
# ليدينا
# ليراك
# ليركب
# ليس
# ليساعدنا
# ليست
# ليسمح
# ليسو
# ليسوا
# ليصبح
# ليصدق
# ليصدقها
# ليصل
# ليصنع
# ليصنعوا
# ليطلب
# ليعرف
# ليعيش
# ليعيل
# ليفعلها
# ليفهم
# ليقود
# ليكونوا
# ليل
# ليلا
# ليله
# ليناسب
# لينجز
# ليوم
# ليومين
# م
# مؤخرا
# مؤخره
# مؤدبا
# مؤقتا
# مؤكدا
# مؤلفه
# مؤلم
# مؤلما
# مؤمنا
# مؤهلا
# مئات
# مئه
# مئويه
# ما
# ماء
# مائه
# مات
# ماتا
# ماتت
# ماتوا
# مادتي
# مادمت
# ماده
# ماذا
# مارايك
# مارس
# مارساذار
# مارك
# ماري
# ماريا
# مازال
# مازالت
# مازلت
# ماضيه
# مافعلته
# ماكد
# ماكر
# مال
# مالا
# مالداعي
# مالذي
# مالك
# مالكم
# ماله
# مالوفا
# مالي
# مانتشستر
# مانع
# ماهر
# ماهرا
# ماهره
# ماهرين
# ماهي
# ماهيه
# مايقود
# مايو
# مباراه
# مبارايات
# مبارك
# مباشره
# مبال
# مبالغه
# مبتديء
# مبتهج
# مبدعا
# مبروك
# مبسوط
# مبكر
# مبكرا
# مبكره
# مبلغ
# مبلل
# مبلول
# مبلوله
# مبني
# مبيعات
# مت
# متاثر
# متاحا
# متاخر
# متاخرا
# متاخره
# متاسف
# متاعب
# متاكد
# متاكدا
# متاكدمتاكده
# متاكده
# متاكدون
# متاكدين
# متبادلا
# متجر
# متجمد
# متجها
# متجهه
# متحدثي
# متدين
# مترا
# مترجم
# مترجمه
# متردده
# متزلج
# متزوج
# متزوجا
# متزوجه
# متسائلا
# متسامحا
# متسع
# متسيقظا
# متشابهان
# متشوق
# متصفح
# متعادلين
# متعاكسان
# متعب
# متعبا
# متعبه
# متعبون
# متعبين
# متعطله
# متفاجئ
# متفاجئه
# متفرغ
# متفوق
# متفوقا
# متقنا
# متمرد
# متميز
# متن
# متناول
# متنوعه
# متهور
# متواصله
# متوتر
# متوترين
# متوجهون
# متورط
# متوفي
# متوقع
# متوقعه
# متوقعين
# متوقف
# متي
# متيقظه
# متيقنا
# مثابرا
# مثال
# مثالا
# مثاليا
# مثاليه
# مثبته
# مثل
# مثلجات
# مثلك
# مثلنا
# مثله
# مثلها
# مثلي
# مثليو
# مثير
# مثيرا
# مثيره
# مجازفا
# مجازون
# مجال
# مجانا
# مجتمعات
# مجتهد
# مجددا
# مجرد
# مجسمات
# مجلات
# مجلد
# مجلس
# مجله
# مجمد
# مجمده
# مجموعات
# مجموعه
# مجنون
# مجنونا
# مجنونه
# مجهدا
# مجهول
# مجيء
# مجيئك
# مجيئه
# مجيئي
# مجيد
# محادثات
# محادثتك
# محاسن
# محاضرته
# محافظين
# محام
# محاميا
# محاولاتنا
# محاوله
# محاولين
# محبطا
# محبي
# محتجز
# محترفين
# محترما
# محتقن
# محتوياتها
# محجوزه
# محددا
# محرج
# محرر
# محسوما
# محصن
# محض
# محطمه
# محطه
# محظوظ
# محظوظه
# محفظتك
# محفظته
# محفظتي
# محفظه
# محفوظه
# محفوف
# محق
# محقا
# محققان
# محققينا
# محقه
# محل
# محليه
# محموما
# مخاطرا
# مخالف
# مخترع
# مختصره
# مختلف
# مختلفان
# مختلفه
# مخجل
# مخربا
# مخرج
# مخطئ
# مخطئا
# مخطئه
# مخطئون
# مخيفه
# مد
# مدار
# مدارس
# مدارسه
# مدخرات
# مدخل
# مدخنا
# مدرب
# مدرس
# مدرسا
# مدرستك
# مدرستنا
# مدرسته
# مدرستها
# مدرستي
# مدرسك
# مدرسه
# مدرسون
# مدرسي
# مدرسيك
# مدرسيه
# مدريد
# مدعاه
# مدعو
# مدعوين
# مدمنا
# مدن
# مده
# مدي
# مديده
# مدير
# مديره
# مدين
# مدينتك
# مدينه
# مذ
# مذاق
# مذاكرتك
# مذعور
# مذكراته
# مذكرتي
# مذنب
# مذهل
# مذهلا
# مذياعك
# مر
# مرابي
# مرات
# مرارا
# مرافقتي
# مراقبه
# مراه
# مراهق
# مراهقا
# مراهقه
# مربكا
# مربيه
# مرت
# مرتاح
# مرتاحا
# مرتبك
# مرتبه
# مرتديا
# مرتفع
# مرتفعه
# مرتين
# مرحبا
# مرحله
# مرر
# مررت
# مرض
# مرضه
# مرضها
# مرطب
# مرغوبا
# مرقط
# مركبه
# مركز
# مركونه
# مرنا
# مره
# مرهق
# مروري
# مروع
# مريبا
# مريح
# مريحا
# مريحه
# مريض
# مريضا
# مريضه
# مريم
# مزاج
# مزارعين
# مزدحم
# مزرعتك
# مزرعته
# مزرعه
# مزعج
# مزعجا
# مزعجه
# مزقت
# مزيد
# مزيدا
# مسؤؤلا
# مسؤليتي
# مسؤول
# مسؤوله
# مسؤولون
# مسؤوليتك
# مسؤوليتنا
# مساء
# مساءا
# مسابقه
# مساحه
# مساعدتك
# مساعدتنا
# مساعدته
# مساعدتي
# مساعده
# مسافات
# مسافرا
# مسافرين
# مسافه
# مسالمه
# مساله
# مسامح
# مسامحته
# مساهمتكم
# مسبقا
# مستحيل
# مستحيله
# مستشفي
# مستشفيات
# مستعجل
# مستعجلا
# مستعجلين
# مستعد
# مستعدا
# مستعده
# مستعدون
# مستعدين
# مستعمل
# مستقبل
# مستقبلا
# مستقبلك
# مستقبلي
# مستقيم
# مستقيما
# مستمده
# مستمع
# مستورده
# مستيقظين
# مسجد
# مسجدا
# مسح
# مسدس
# مسدسا
# مسدسي
# مسرحيه
# مسرعا
# مسرور
# مسرورا
# مسروره
# مسرورون
# مسطحه
# مسعد
# مسقط
# مسكون
# مسكين
# مسلطه
# مسلم
# مسليا
# مسموحا
# مشابهه
# مشاعرك
# مشاعره
# مشاعري
# مشاغب
# مشاكل
# مشاهده
# مشتاق
# مشتر
# مشتقه
# مشرق
# مشروب
# مشروع
# مشغل
# مشغول
# مشغولا
# مشغولان
# مشغوله
# مشغولين
# مشكل
# مشكلتك
# مشكله
# مشمس
# مشمسه
# مشهور
# مشهورا
# مشهوره
# مشوش
# مشيا
# مشيت
# مشينا
# مصائب
# مصابا
# مصاحبه
# مصادر
# مصادري
# مصاريفه
# مصداقيه
# مصدر
# مصدرها
# مصدقا
# مصر
# مصروفا
# مصروفات
# مصعد
# مصففي
# مصممه
# مصنع
# مصنوعه
# مصيب
# مصيري
# مضاده
# مضايقه
# مضت
# مضحكا
# مضحكه
# مضخما
# مضر
# مضرب
# مضربك
# مضره
# مضطرا
# مضي
# مطابق
# مطاعم
# مطرا
# مطرقه
# مطريتك
# مطعم
# مطعما
# مطعمنا
# مطلق
# مطلقا
# مطلقه
# مطلوب
# مطلي
# مطيع
# مطيعون
# مظلتك
# مظلتي
# مظلم
# مظلمه
# مظله
# مظهر
# مظهرك
# مظهره
# مظهرهم
# مظهري
# مع
# معا
# معارضه
# معاقبتهم
# معالجه
# معاملتك
# معاملته
# معامله
# معاهده
# معاير
# معاينه
# معتاد
# معتادا
# معتاده
# معتدل
# معجب
# معجبا
# معجبه
# معجما
# معجون
# معدل
# معدلات
# معدنيه
# معدوده
# معرض
# معرفتك
# معرفته
# معرفه
# معركه
# معروف
# معروفا
# معصمها
# معصوم
# معضله
# معطف
# معطفا
# معطفك
# معطفه
# معطفها
# معظم
# معقده
# معقول
# معك
# معلقه
# معلم
# معلما
# معلمنا
# معلمه
# معلمون
# معلمينا
# معلوم
# معلوما
# معلومات
# معمر
# معنا
# معناها
# معنوياته
# معني
# معنيان
# معه
# معها
# معهم
# معي
# معيشتنا
# معين
# معينه
# مغادرتك
# مغادرتي
# مغادره
# مغامره
# مغرم
# مغرمه
# مغص
# مغطاه
# مغطي
# مغلق
# مغلقا
# مغلقه
# مغموسا
# مغني
# مغنيا
# مغنيه
# مفاتيح
# مفاتيحك
# مفاتيحها
# مفاتيحي
# مفاجئا
# مفاجاه
# مفاصلي
# مفاوضات
# مفتاح
# مفتاحا
# مفتاحك
# مفتاحي
# مفترضا
# مفتوح
# مفتوحا
# مفتوحتان
# مفتوحتين
# مفتوحه
# مفضلاتي
# مفعمون
# مفقوده
# مفلس
# مفهوما
# مفيد
# مفيده
# مقابل
# مقابله
# مقارنه
# مقاس
# مقاعدكم
# مقاعدنا
# مقبول
# مقتنع
# مقتنعا
# مقدسه
# مقدما
# مقربان
# مقرف
# مقروءه
# مقصد
# مقصك
# مقعدا
# مقعدك
# مقفل
# مقهي
# مقولات
# مكاتبنا
# مكالمه
# مكان
# مكانا
# مكانك
# مكانه
# مكاني
# مكبر
# مكتئبا
# مكتب
# مكتبك
# مكتبه
# مكتبي
# مكتظ
# مكتظا
# مكتوب
# مكسور
# مكسوره
# مكعب
# مكلفه
# ملء
# ملئت
# ملئي
# ملا
# ملابس
# ملابسا
# ملابسك
# ملابسي
# ملات
# ملاحظه
# ملاحقتنا
# ملاك
# ملاكا
# ملاين
# ملبوس
# ملت
# ملحوظه
# ملعب
# ملعقته
# ملقط
# ملك
# ملكا
# ملكك
# ملكه
# ملكي
# مللت
# مليء
# مليئا
# مليئه
# مليار
# مليون
# مما
# ممارسه
# ممتاز
# ممتازه
# ممتع
# ممتعا
# ممتعه
# ممتلئ
# ممتن
# ممتنون
# ممثل
# ممرضه
# ممطر
# ممكن
# ممكنه
# ممل
# مملا
# ممله
# مميز
# من
# منا
# مناخنا
# مناداتي
# مناسب
# مناسبا
# مناسبات
# مناسبه
# مناطق
# مناعه
# مناقشه
# منتبهين
# منتجاتكم
# منتجع
# منتصف
# منتعشين
# منحت
# منحتني
# منحوس
# منخفض
# مندهش
# منذ
# منزل
# منزلا
# منزلك
# منزلنا
# منزله
# منزلهم
# منزلي
# منزليه
# منشفه
# منطقيا
# منطقيه
# منظر
# منظما
# منعنا
# منفقي
# منقارها
# منك
# منكسرا
# منه
# منها
# منهكين
# منهم
# منهما
# مني
# مهام
# مهتم
# مهتما
# مهدد
# مهذب
# مهذبا
# مهرب
# مهله
# مهم
# مهما
# مهمته
# مهمتها
# مهمتي
# مهملا
# مهمه
# مهنتك
# مهندسون
# مهنه
# مواصفاته
# مواطن
# مواطني
# موافق
# موافقته
# مواقع
# موت
# موتها
# موجه
# موجهه
# موجود
# موجودا
# موجوده
# موسكو
# موسم
# موسمنا
# موسيقاك
# موسيقاي
# موسيقي
# موضه
# موضوع
# موظف
# موعد
# موعدا
# موعدك
# موعدها
# موقع
# موقعنا
# موقف
# موقفي
# موقن
# مولده
# مولع
# موهوب
# مياه
# ميت
# ميتا
# ميته
# ميري
# ميزانيه
# ميعاد
# ميعادنا
# ميل
# ميلاد
# ميلادك
# ميلاده
# ميلادها
# ميلادي
# ميلاديه
# ميناء
# نائم
# نائما
# نائمه
# نائمون
# ناجحا
# ناجحه
# ناجل
# ناحيه
# ناخذ
# نادرا
# نادلا
# نادما
# نادني
# نادي
# ناديت
# نادينا
# ناري
# ناريه
# ناسف
# ناضج
# ناعم
# نافعه
# نافوره
# ناقد
# ناقشت
# ناقشنا
# ناقشناه
# ناقصه
# ناكل
# نام
# ناما
# نامل
# ناولني
# نباتات
# نبح
# نبحت
# نبحث
# نبدا
# نبضه
# نبقي
# نبهني
# نبوه
# نتائج
# نتاكد
# نتبع
# نتبعكم
# نتجنب
# نتحدث
# نتحمل
# نتخلص
# نتركها
# نتس
# نتساءل
# نتظاهر
# نتعلم
# نتفائل
# نتفق
# نتقاسم
# نتكلم
# نتمشي
# نتواصل
# نتواعد
# نتوقع
# نتيجه
# نجا
# نجابهها
# نجاحك
# نجاحنا
# نجاحه
# نجحت
# نجحنا
# نجوم
# نحافتك
# نحب
# نحتاج
# نحترم
# نحجز
# نحصل
# نحل
# نحمل
# نحمي
# نحن
# نحو
# نحوي
# نحيف
# نحيفا
# نحيفه
# نختبئ
# نختلف
# نخرج
# نخسر
# نخطئ
# ندب
# ندخن
# ندمت
# نذهب
# نراه
# نرتاح
# نرحب
# نرغب
# نرفع
# نرقص
# نره
# نرها
# نرويجي
# نري
# نريد
# نزرع
# نزل
# نزلت
# نزلنا
# نزهتنا
# نزول
# نساء
# نساعد
# نساعده
# نسبح
# نسبيا
# نستبق
# نستخدمه
# نستطع
# نستطيع
# نستعجل
# نستعد
# نستقل
# نستمع
# نستهلك
# نسختين
# نسدد
# نسطيع
# نسقي
# نسمع
# نسمه
# نسي
# نسيان
# نسيانك
# نسيت
# نسيتني
# نسير
# نشاتتربيت
# نشاطا
# نشانا
# نشاهد
# نشتري
# نشجع
# نشرت
# نشعر
# نشك
# نشكرك
# نشكل
# نشيدا
# نصائحك
# نصبح
# نصحتني
# نصحته
# نصحني
# نصحها
# نصحهها
# نصدر
# نصدق
# نصف
# نصل
# نصلح
# نصنع
# نصيحتك
# نصيحته
# نصيحتي
# نصيحه
# نضج
# نطاق
# نطقها
# نطقي
# نطهي
# نظارات
# نظاراتي
# نظارتك
# نظارتي
# نظاره
# نظام
# نظر
# نظرت
# نظرته
# نظره
# نظريا
# نظريه
# نظف
# نظفت
# نظفنا
# نظفي
# نظم
# نظن
# نظيره
# نظيف
# نظيفا
# نظيفتان
# نظيفه
# نعالي
# نعتمد
# نعد
# نعرف
# نعرفه
# نعرفها
# نعسان
# نعطي
# نعكس
# نعلم
# نعليك
# نعم
# نعمل
# نعمه
# نعود
# نعيش
# نعيل
# نغير
# نفخر
# نفد
# نفذ
# نفس
# نفسك
# نفسه
# نفسها
# نفسي
# نفصلها
# نفط
# نفطر
# نفعل
# نفقتي
# نفكر
# نفهم
# نفوز
# نقاط
# نقاوه
# نقبل
# نقدر
# نقديه
# نقسم
# نقص
# نقطه
# نقلب
# نقلته
# نقم
# نقود
# نقودك
# نقودي
# نقول
# نقوم
# نقي
# نكته
# نكمل
# نكهه
# نكون
# نلتقي
# نلعب
# نلغي
# نلق
# نمت
# نمر
# نمط
# نمكث
# نملك
# نمنا
# نموا
# نموذج
# نموذجي
# نناقشه
# ننتظر
# ننس
# ننسي
# ننقسم
# ننهي
# نهائي
# نهائيا
# نهاري
# نهاني
# نهايه
# نهتم
# نهر
# نهض
# نهم
# نواجه
# نواحي
# نواياه
# نوبه
# نوصله
# نوع
# نوعا
# نوم
# نومك
# نومه
# نومها
# نومي
# نويته
# نويل
# نيابه
# نيتي
# نيويورك
# هؤلاء
# ها
# هائج
# هاتان
# هاتفك
# هاتفني
# هاتفه
# هاتفي
# هاتفيه
# هاتين
# هاجم
# هاجمنا
# هادئ
# هادئا
# هادئه
# هادئين
# هاذا
# هاربا
# هارفارد
# هاك
# هام
# هاما
# هاملت
# هاهنا
# هاهي
# هاواي
# هبط
# هبطت
# هتف
# هتلر
# هجر
# هدء
# هدات
# هدايا
# هدفا
# هدفك
# هدفهم
# هدفي
# هدوء
# هدوئك
# هديتك
# هديتي
# هديه
# هذا
# هذان
# هذه
# هذين
# هر
# هراء
# هرب
# هطل
# هطول
# هطوله
# هفوه
# هكذا
# هل
# هلا
# هلاما
# هم
# هما
# هن
# هنا
# هناته
# هناك
# هنالك
# هو
# هوائيه
# هوايتها
# هوايتي
# هوجمنا
# هوجموا
# هوكايدو
# هوكي
# هونج
# هونولولو
# هي
# هيئه
# هيا
# هينا
# و
# واباء
# وابتسمت
# وابحث
# وابنتين
# وابنه
# وابني
# وابيض
# واثق
# واثقا
# واجب
# واجبا
# واجباتك
# واجباتها
# واجباتي
# واجبك
# واجبه
# واجبي
# واجلس
# واجه
# واحد
# واحدا
# واحده
# واحمر
# واخبرته
# واخبريني
# واخذ
# واخي
# واخيرا
# وادع
# واراد
# واربعين
# وارد
# واريد
# واسبح
# واسمعني
# واشنطن
# واصبحا
# واصدقاءها
# واصل
# واصلت
# واضح
# واضحا
# واعد
# واعزب
# واغسل
# واغسلي
# واغلق
# وافتقدك
# وافق
# وافقت
# وافقتها
# وافقني
# واقابلك
# واقع
# واقعيه
# واقف
# واكلوا
# والا
# والاخر
# والاخري
# والاخير
# والاستماع
# والاهم
# والبعض
# والتحرك
# والتدخين
# والتطبيق
# والتقط
# والثلاثاء
# والجبنه
# والحراره
# والخطا
# والدا
# والداي
# والدتك
# والدته
# والدتها
# والدتي
# والدك
# والدنا
# والده
# والدها
# والدي
# والديك
# والديها
# والراحه
# والسكين
# والسياسه
# والشعير
# والصين
# والعافيه
# والعيش
# والغولف
# والفرنسيه
# والفلفل
# والقاه
# والقوه
# والقي
# والكبيره
# والكتابه
# والكذابين
# والكذب
# والكره
# والكلاب
# واللحم
# واللعب
# والمرضي
# والمسيحيه
# والمشاهده
# والمكسيك
# والمنجل
# والنصف
# والنوافذ
# والنوم
# والوحيد
# واليابانيه
# واليهوديه
# وامريكا
# وامي
# وان
# وانا
# وانت
# وانتم
# وانهار
# واهتماماتك
# واين
# وبالطريقه
# وبخ
# وبختني
# وبخني
# وبشده
# وبضعه
# وبعد
# وبعدها
# وبعضهم
# وبكيت
# وبنطالا
# وبيتك
# وبين
# وبينك
# وبينها
# وتحادثه
# وتحبني
# وتسامحه
# وتستريح
# وتسعمئه
# وتقاليده
# وتكرارا
# وتلك
# وتوفي
# وتوم
# وثلاثه
# وثم
# وثمان
# وثمانين
# وجب
# وجبه
# وجت
# وجد
# وجدت
# وجدته
# وجدنا
# وجدناه
# وجدناها
# وجه
# وجها
# وجهت
# وجهتك
# وجهك
# وجهه
# وجهها
# وجهي
# وجود
# وجودك
# وجودي
# وحاولت
# وحدك
# وحدنا
# وحده
# وحدها
# وحدي
# وحش
# وحيد
# وحيدا
# وحيده
# وختك
# وخرجت
# وخمسون
# وخمسين
# وخيالنا
# وخيمه
# وداعا
# ودودا
# وذاك
# وذكي
# وذنب
# وذهب
# وذهبت
# ورؤيه
# وراء
# وراءك
# وراءه
# ورايت
# وردا
# وردائك
# ورده
# ورديا
# ورشه
# ورطه
# ورفض
# ورق
# ورقه
# ورود
# وزع
# وزن
# وزنها
# وزوجه
# وسادتي
# وساده
# وساعات
# وساعدنا
# وساعدني
# وسال
# وسالتني
# وسبعه
# وستلحق
# وستنجح
# وسط
# وسعك
# وسعه
# وسليما
# وسهلا
# وسهله
# وسيحترمك
# وسيساعدك
# وسيكون
# وسيله
# وسيم
# وسيما
# وشاحي
# وشاننا
# وشانها
# وشاني
# وشاهد
# وشك
# وصاله
# وصفتني
# وصل
# وصلت
# وصلتني
# وصلنا
# وصلني
# وصلوا
# وصول
# وصوله
# وصولي
# وصيته
# وصيه
# وضح
# وضحاها
# وضحت
# وضع
# وضعت
# وضعها
# وضوح
# وطلبو
# وطنهم
# وطنيا
# وظيفتك
# وظيفته
# وظيفتي
# وظيفه
# وعاد
# وعالم
# وعاني
# وعد
# وعدا
# وعدت
# وعدني
# وعده
# وعشرون
# وعشرين
# وعطشا
# وعقلاني
# وعمل
# وعوده
# وعيه
# وغير
# وفاته
# وفقا
# وفقد
# وفمك
# وفي
# وقال
# وقبلت
# وقبيح
# وقت
# وقتا
# وقتك
# وقتي
# وقح
# وقحا
# وقدم
# وقط
# وقطه
# وقع
# وقعت
# وقعنا
# وقعوا
# وقف
# وقفت
# وقفنا
# وقلت
# وقوه
# وقوي
# وكاله
# وكان
# وكانك
# وكاننا
# وكانه
# وكانها
# وكاني
# وكسر
# وكل
# وكلتا
# وكنت
# وكوريا
# وكيف
# ولا
# ولادته
# ولاعه
# ولد
# ولدا
# ولدت
# ولدي
# ولذا
# ولكن
# ولكنني
# ولكنه
# ولكنها
# ولكني
# ولم
# ولن
# وله
# ولهذا
# ولو
# ولوعا
# ولي
# وليس
# وليست
# وما
# ومات
# وماري
# ومازال
# ومثير
# ومدرسين
# ومشي
# ومصاعب
# ومضيعه
# ومع
# ومما
# ومن
# ومنهكا
# وميري
# ونحن
# ونرقص
# ونساء
# ونظر
# ونظيف
# ونقف
# وهذه
# وهم
# وهناك
# وهو
# وهي
# وواضح
# ويدك
# ويدي
# ويراها
# ويستطيع
# ويستمتع
# ويفوتني
# ويمكن
# يؤثر
# يؤثرعلي
# يؤدي
# يؤذن
# يؤذي
# يؤلم
# يؤلمني
# يؤمن
# يا
# ياابي
# يااصحاب
# ياباني
# يابانيا
# يابانين
# يابانيه
# يابانيون
# يات
# ياتوم
# ياتون
# ياتي
# ياخذ
# ياخذني
# ياخذها
# يادكتور
# يارفاق
# ياسيدي
# ياشباب
# ياصاح
# يافتي
# يافعا
# ياكل
# ياكله
# ياكلون
# يالك
# ياماري
# يامل
# يباركك
# يبتسم
# يبحث
# يبدا
# يبدو
# يبدوا
# يبدون
# يبعث
# يبعد
# يبق
# يبقوا
# يبقي
# يبكي
# يبلغ
# يبني
# يبيع
# يبيعون
# يتاخر
# يتاذ
# يتاذي
# يتالف
# يتبضع
# يتبعني
# يتجاهلونني
# يتجاوب
# يتجاوز
# يتجمد
# يتجنب
# يتجه
# يتحدث
# يتحدثون
# يتحرك
# يتحركون
# يتحسن
# يتخذ
# يتخطون
# يتخطي
# يتخلص
# يتخلي
# يتدخلوا
# يتدرب
# يتذكر
# يتذمر
# يترجم
# يترك
# يتزوج
# يتزوجا
# يتزوجها
# يتساءلون
# يتسول
# يتصافح
# يتصرف
# يتصل
# يتطلب
# يتعامل
# يتعرف
# يتعفن
# يتعلق
# يتعلمون
# يتغذي
# يتغير
# يتفق
# يتفقون
# يتقدمون
# يتقرر
# يتقن
# يتكلم
# يتكلمون
# يتم
# يتمحور
# يتناقص
# يتناول
# يتوجب
# يتوقع
# يتوقعه
# يتوقف
# يتيم
# يثق
# يجب
# يجتاح
# يجتهد
# يجد
# يجدر
# يجدوا
# يجرب
# يجرح
# يجري
# يجعل
# يجعلك
# يجعلني
# يجف
# يجلبها
# يجلس
# يجمع
# يجني
# يجهز
# يجهل
# يجوز
# يحادث
# يحاول
# يحب
# يحبس
# يحبك
# يحبنا
# يحبني
# يحبه
# يحبها
# يحبون
# يحبونني
# يحبونها
# يحتاج
# يحتاجه
# يحتاجها
# يحتاجون
# يحتاجونه
# يحترق
# يحتضر
# يحتوي
# يحدث
# يحدق
# يحذرني
# يحزنك
# يحسن
# يحص
# يحصل
# يحضر
# يحفر
# يحفز
# يحقق
# يحكني
# يحل
# يحمل
# يحين
# يخاف
# يخبرك
# يخبرنا
# يختلط
# يخدعني
# يخدعونا
# يخرجون
# يخرق
# يخسره
# يخصك
# يخصني
# يخطئون
# يخطر
# يخطط
# يخف
# يخفف
# يخفي
# يخلد
# يخلف
# يخوض
# يد
# يداك
# يدخل
# يدخن
# يدرب
# يدرس
# يدرسك
# يدرسون
# يدري
# يدعني
# يدعو
# يدعوني
# يدعي
# يدفع
# يدك
# يده
# يدها
# يدوس
# يدوم
# يدي
# يدير
# يديك
# يديه
# يديها
# يذكر
# يذكرني
# يذهب
# يذهبون
# ير
# يراس
# يراسل
# يرافقني
# يراقبك
# يراقبني
# يراقبون
# يراك
# يرام
# يرانا
# يراه
# يراها
# يراودني
# يربي
# يرتدي
# يرث
# يرجع
# يرجي
# يرحل
# يرد
# يرسب
# يرسل
# يرسلوا
# يرسمون
# يرغب
# يرفع
# يرق
# يرقد
# يرقص
# يركب
# يركض
# يركن
# يرمز
# يرمزان
# يروق
# يري
# يريد
# يريدك
# يريدني
# يريده
# يريدون
# يريه
# يزال
# يزحف
# يزرع
# يزعجك
# يزعجني
# يزن
# يزور
# يزيد
# يسارك
# يساعد
# يساعدك
# يساعدنا
# يساعدني
# يسافر
# يسال
# يساوي
# يسبب
# يسبح
# يسبحان
# يسبق
# يستحسن
# يستحق
# يستحمون
# يستحيل
# يستخدم
# يستريح
# يستسلم
# يستسلموا
# يستطع
# يستطيع
# يستعد
# يستعدان
# يستعيد
# يستغرق
# يستلقي
# يستمتع
# يستمع
# يستمعون
# يستهان
# يستهدفون
# يستوعب
# يستيقظ
# يسرب
# يسرقون
# يسعدني
# يسعك
# يسعه
# يسعها
# يسقي
# يسكن
# يسمح
# يسمع
# يسمعانا
# يسمعك
# يسمعها
# يسمعونا
# يسمي
# يسوء
# يسوع
# يسوق
# يسير
# يسيطر
# يسيل
# يشارك
# يشاهد
# يشبه
# يشتبه
# يشتري
# يشتكين
# يشجعها
# يشرب
# يشربون
# يشعر
# يشعرني
# يشعرون
# يشعل
# يشكو
# يشهد
# يشوي
# يصاب
# يصاحب
# يصب
# يصبح
# يصدق
# يصدقك
# يصدقنا
# يصدقني
# يصدقها
# يصرخ
# يصعب
# يصغي
# يصل
# يصلح
# يصلحوا
# يصلون
# يصلي
# يصنع
# يصير
# يضحك
# يضر
# يضربني
# يضع
# يطالبون
# يطرح
# يطرد
# يطفئ
# يطفو
# يطلق
# يطير
# يطيق
# يطيقه
# يظل
# يظن
# يظننا
# يظنون
# يظهر
# يعامل
# يعاملنا
# يعاملوني
# يعانون
# يعاني
# يعبدون
# يعتذر
# يعترض
# يعتقد
# يعتقدون
# يعتمد
# يعجبك
# يعجبني
# يعجبه
# يعد
# يعر
# يعرف
# يعرفان
# يعرفك
# يعرفنا
# يعرفني
# يعرفون
# يعرفوني
# يعزف
# يعشقون
# يعطي
# يعطينا
# يعلم
# يعلمك
# يعمل
# يعمله
# يعنونه
# يعنيك
# يعنيني
# يعود
# يعودوا
# يعي
# يعيد
# يعيش
# يعيشوا
# يعيشون
# يغادر
# يغادروا
# يغرق
# يغسل
# يغسلون
# يغش
# يغلب
# يغلق
# يغني
# يغيب
# يغير
# يغيظني
# يفاجئني
# يفتح
# يفترض
# يفتقر
# يفشل
# يفضل
# يفطر
# يفعل
# يفعله
# يفعلها
# يفعلون
# يفعلوها
# يفقد
# يفكر
# يفكرني
# يفهم
# يفهمني
# يفهمه
# يفوت
# يفوز
# يفوق
# يفي
# يقابلني
# يقاتل
# يقارب
# يقارن
# يقال
# يقبل
# يقتل
# يقتلني
# يقدر
# يقدم
# يقرا
# يقرر
# يقرضني
# يقصد
# يقضي
# يقطع
# يقع
# يقف
# يقفز
# يقل
# يقلع
# يقلق
# يقلقك
# يقلم
# يقود
# يقول
# يقوله
# يقولوا
# يقولون
# يقوم
# يقومو
# يقومون
# يكافحون
# يكبر
# يكبرني
# يكتب
# يكتبون
# يكثر
# يكرر
# يكره
# يكرهان
# يكرهك
# يكرهنا
# يكرهني
# يكرهون
# يكرهونك
# يكرهونه
# يكفي
# يكفيني
# يكفيهم
# يكلمني
# يكن
# يكون
# يكونوا
# يلاحقنا
# يلبس
# يلتزم
# يلتقط
# يلزم
# يلعب
# يلعبون
# يلمس
# يماثل
# يمتد
# يمثل
# يمزح
# يمزق
# يمشوا
# يمشي
# يمكن
# يمكنك
# يمكننا
# يمكنني
# يمكنه
# يمكنها
# يمكنهم
# يملك
# يملكون
# يمنع
# يمنعنا
# يموت
# يموتون
# يميزها
# يمين
# يمينا
# ين
# ينادي
# ينازه
# يناسبك
# يناسبني
# ينام
# يناير
# ينبح
# ينبغي
# ينتبهوا
# ينتج
# ينتظر
# ينتظرك
# ينتظرون
# ينتظرونك
# ينتفخ
# ينتهي
# ينج
# ينجح
# ينجحا
# ينجحوا
# ينزف
# ينزل
# ينس
# ينساه
# ينسي
# ينضم
# ينطق
# ينظر
# ينظف
# ينفق
# ينقص
# ينقل
# ينكر
# ينكسر
# يهاجر
# يهتز
# يهتم
# يهدد
# يهدر
# يهدي
# يهرب
# يهطل
# يهم
# يهمني
# يهمه
# يواجه
# يوافقك
# يوافقني
# يوجد
# يوحي
# يود
# يورو
# يوزن
# يوسع
# يوشك
# يوصلني
# يوصي
# يوظف
# يوقفك
# يولد
# يوليو
# يوليوتموز
# يوم
# يوما
# يومها
# يوميا
# يومياتك
# يومين
# يوناني
# يونايتد
# يونيو
# يونيوحزيران
# ٱخر

# %%
#Find maximum sentence length in  the source and target data
source_length_list=[]
for l in lines.source:
    source_length_list.append(len(l.split(' ')))
max_source_length= max(source_length_list)
print(" Max length of the source sentence",max_source_length)
target_length_list=[]
for l in lines.target:
    target_length_list.append(len(l.split(' ')))
max_target_length= max(target_length_list)
print(" Max length of the target sentence",max_target_length)
# Out:
#  Max length of the source sentence 34
#  Max length of the target sentence 38

# %%
# creating a word to index(word2idx) for source and target
source_word2idx= dict([(word, i+1) for i,word in enumerate(source_words)])
target_word2idx=dict([(word, i+1) for i, word in enumerate(target_words)])

# %%
#creating a dictionary for index to word for source and target vocabulary
source_idx2word= dict([(i, word) for word, i in  source_word2idx.items()])
print(source_idx2word)
target_idx2word =dict([(i, word) for word, i in target_word2idx.items()])
# Out:
# {1: 'a', 2: 'abandon', 3: 'ability', 4: 'able', 5: 'aboard', 6: 'abomination', 7: 'abortion', 8: 'about', 9: 'above', 10: 'abroad', 11: 'absence', 12: 'absent', 13: 'absolute', 14: 'absolutely', 15: 'absorb', 16: 'abuse', 17: 'abused', 18: 'abusing', 19: 'accelerated', 20: 'accent', 21: 'accept', 22: 'accepted', 23: 'accepting', 24: 'accident', 25: 'accidents', 26: 'accompanies', 27: 'accompany', 28: 'accomplished', 29: 'account', 30: 'accurate', 31: 'accused', 32: 'accustomed', 33: 'ace', 34: 'aces', 35: 'ache', 36: 'achieved', 37: 'achilles', 38: 'acknowledge', 39: 'acquaintance', 40: 'acquainted', 41: 'acquisition', 42: 'across', 43: 'act', 44: 'acting', 45: 'action', 46: 'actions', 47: 'active', 48: 'actor', 49: 'actress', 50: 'acts', 51: 'actually', 52: 'adapted', 53: 'add', 54: 'added', 55: 'addicted', 56: 'address', 57: 'addressed', 58: 'adjust', 59: 'adjusting', 60: 'admire', 61: 'admit', 62: 'adopt', 63: 'ads', 64: 'adults', 65: 'advance', 66: 'advances', 67: 'advantage', 68: 'adventure', 69: 'adversity', 70: 'advertisements', 71: 'advice', 72: 'advise', 73: 'advised', 74: 'affair', 75: 'affect', 76: 'affected', 77: 'afford', 78: 'afraid', 79: 'africa', 80: 'after', 81: 'afterlife', 82: 'afternoon', 83: 'again', 84: 'against', 85: 'age', 86: 'agency', 87: 'ago', 88: 'agree', 89: 'agreed', 90: 'agrees', 91: 'ahead', 92: 'aid', 93: 'aim', 94: 'aimed', 95: 'aint', 96: 'air', 97: 'airmail', 98: 'airplane', 99: 'airport', 100: 'alarm', 101: 'albert', 102: 'alcohol', 103: 'alert', 104: 'alexandria', 105: 'alike', 106: 'alive', 107: 'all', 108: 'allergic', 109: 'allergy', 110: 'alley', 111: 'allow', 112: 'allowance', 113: 'allowed', 114: 'almost', 115: 'alone', 116: 'along', 117: 'aloud', 118: 'already', 119: 'also', 120: 'alter', 121: 'alternative', 122: 'although', 123: 'always', 124: 'am', 125: 'amazes', 126: 'amazing', 127: 'ambassador', 128: 'ambition', 129: 'ambulance', 130: 'america', 131: 'american', 132: 'americans', 133: 'amiss', 134: 'among', 135: 'amount', 136: 'amplifier', 137: 'amused', 138: 'an', 139: 'ancestors', 140: 'ancient', 141: 'and', 142: 'angel', 143: 'anger', 144: 'angry', 145: 'animal', 146: 'animals', 147: 'annexed', 148: 'announced', 149: 'annoying', 150: 'another', 151: 'answer', 152: 'answered', 153: 'answering', 154: 'ant', 155: 'anthem', 156: 'anticipating', 157: 'anticonstitutionnellement', 158: 'ants', 159: 'anxious', 160: 'any', 161: 'anybody', 162: 'anymore', 163: 'anyone', 164: 'anything', 165: 'anytime', 166: 'anyway', 167: 'anyways', 168: 'anywhere', 169: 'apart', 170: 'apartment', 171: 'apologies', 172: 'apologize', 173: 'apologized', 174: 'apology', 175: 'apparent', 176: 'apparently', 177: 'appear', 178: 'appearance', 179: 'appearances', 180: 'appeared', 181: 'appears', 182: 'applauded', 183: 'apple', 184: 'apples', 185: 'application', 186: 'applications', 187: 'appointment', 188: 'appreciate', 189: 'appreciates', 190: 'appreciation', 191: 'approached', 192: 'appropriate', 193: 'approve', 194: 'approved', 195: 'april', 196: 'arab', 197: 'arabic', 198: 'arabs', 199: 'arbitrarily', 200: 'arctic', 201: 'are', 202: 'area', 203: 'arent', 204: 'argentine', 205: 'argue', 206: 'arguing', 207: 'arm', 208: 'army', 209: 'around', 210: 'arrangements', 211: 'arrested', 212: 'arrive', 213: 'arrived', 214: 'arrives', 215: 'arriving', 216: 'arrogance', 217: 'art', 218: 'article', 219: 'articles', 220: 'artificial', 221: 'artist', 222: 'artists', 223: 'as', 224: 'asakusa', 225: 'asap', 226: 'ashamed', 227: 'asia', 228: 'aside', 229: 'ask', 230: 'asked', 231: 'asking', 232: 'asks', 233: 'asleep', 234: 'assist', 235: 'assume', 236: 'assumed', 237: 'astronaut', 238: 'astronomy', 239: 'astrophysicist', 240: 'at', 241: 'ate', 242: 'atlantis', 243: 'atomic', 244: 'attached', 245: 'attack', 246: 'attacked', 247: 'attempt', 248: 'attempted', 249: 'attempts', 250: 'attend', 251: 'attended', 252: 'attention', 253: 'attic', 254: 'attitude', 255: 'attracted', 256: 'attraction', 257: 'attractions', 258: 'audience' ...

# %% [markdown]
# ###Glove Embedding

# %%
#retreived from https://www.kaggle.com/thanakomsn/glove6b300dtxt
MAX_SENTENCE_LENGTH = 35
MAX_NUM_WORDS = 10000
EMBEDDING_SIZE = 300

# %%
embeddings_dictionary = dict()

glove_file = open(r'/content/drive/MyDrive/glove.6B.300d.txt', encoding="utf8")

for line in glove_file:
    records = line.split()
    word = records[0]
    vector_dimensions = asarray(records[1:], dtype='float32')
    embeddings_dictionary[word] = vector_dimensions
glove_file.close()

# %%
num_words = min(MAX_NUM_WORDS, len(source_word2idx) + 1)
embedding_matrix = zeros((num_words, EMBEDDING_SIZE))
for word, index in source_word2idx.items():
    embedding_vector = embeddings_dictionary.get(word)
    if embedding_vector is not None:
        embedding_matrix[index] = embedding_vector

# %%
embedding_layer = Embedding(num_words, EMBEDDING_SIZE, weights=[embedding_matrix], input_length=max_source_length)

# %% [markdown]
# ###Train Test Split

# %%
#Shuffle the data
lines = shuffle(lines)

# %%
# Train - Test Split
X, y = lines.source, lines.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
X_train.shape, X_test.shape
# Out:
# ((9334,), (2334,))

# %% [markdown]
# ##Padding

# %%
# Input tokens for encoder zero padded
num_encoder_tokens=len(source_words)+1

# %%
# Input tokens for decoder zero padded
num_decoder_tokens=len(target_words) +1

# %% [markdown]
# ###Seq2Seq Model Definition

# %%
def generate_batch(X = X_train, y = y_train, batch_size = 128):
    ''' Generate a batch of data '''
    while True:
        for j in range(0, len(X), batch_size):
            encoder_input_data = np.zeros((batch_size, max_source_length),dtype='float32')
            decoder_input_data = np.zeros((batch_size, max_target_length),dtype='float32')
            decoder_target_data = np.zeros((batch_size, max_target_length, num_decoder_tokens),dtype='float32')
            for i, (input_text, target_text) in enumerate(zip(X[j:j+batch_size], y[j:j+batch_size])):
                for t, word in enumerate(input_text.split()):
                  encoder_input_data[i, t] = source_word2idx[word] 
                for t, word in enumerate(target_text.split()):
                    if t<len(target_text.split())-1:
                        decoder_input_data[i, t] = target_word2idx[word] # decoder input seq
                    if t>0:
                        # decoder target sequence (one hot encoded)
                        # does not include the START_ token
                        # Offset by one timestep
                        #print(word)
                        decoder_target_data[i, t - 1, target_word2idx[word]] = 1.
                    
            yield([encoder_input_data, decoder_input_data], decoder_target_data)

# %%
train_samples = len(X_train)
val_samples = len(X_test)
batch_size = 64
epochs = 100
latent_dim=300

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None,))
#enc_emb =  Embedding(num_encoder_tokens, latent_dim, mask_zero = True)(encoder_inputs)
enc_emb =  Embedding(num_words, EMBEDDING_SIZE, weights=[embedding_matrix], input_length=max_source_length)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(enc_emb)
dropout = Dropout(rate=0.5)
encoder_outputs = dropout(encoder_outputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# %%
# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))
dec_emb_layer = Embedding(num_decoder_tokens, latent_dim, mask_zero = True)
dec_emb = dec_emb_layer(decoder_inputs)
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(dec_emb,
                                     initial_state=encoder_states)
dropout = Dropout(rate=0.5)
decoder_outputs = dropout(decoder_outputs)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
# Define the model that takes encoder and decoder input 
# to output decoder_outputs
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %% [markdown]
# ###Seq2Seq Model Training

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

# %%
train_samples = len(X_train) # Total Training samples
val_samples = len(X_test)    # Total validation or test samples
batch_size = 128
epochs = 30

# %%
history=model.fit_generator(generator = generate_batch(X_train, y_train, batch_size = batch_size),
                    steps_per_epoch = train_samples//batch_size,
                    epochs=epochs,
                    validation_data = generate_batch(X_test, y_test, batch_size = batch_size),
                    validation_steps = val_samples//batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/30
# 72/72 [==============================] - 284s 4s/step - loss: 1.0105 - acc: 0.1799 - val_loss: 0.9077 - val_acc: 0.2026
# Epoch 2/30
# 72/72 [==============================] - 276s 4s/step - loss: 0.8791 - acc: 0.2002 - val_loss: 0.9092 - val_acc: 0.2027
# Epoch 3/30
# 72/72 [==============================] - 274s 4s/step - loss: 0.8689 - acc: 0.2012 - val_loss: 0.9062 - val_acc: 0.2055
# Epoch 4/30
# 72/72 [==============================] - 274s 4s/step - loss: 0.8537 - acc: 0.2054 - val_loss: 0.8924 - val_acc: 0.2118
# Epoch 5/30
# 72/72 [==============================] - 280s 4s/step - loss: 0.8385 - acc: 0.2139 - val_loss: 0.8855 - val_acc: 0.2220
# Epoch 6/30
# 72/72 [==============================] - 278s 4s/step - loss: 0.8185 - acc: 0.2245 - val_loss: 0.8757 - val_acc: 0.2330
# Epoch 7/30
# 72/72 [==============================] - 273s 4s/step - loss: 0.8018 - acc: 0.2387 - val_loss: 0.8649 - val_acc: 0.2423
# Epoch 8/30
# 72/72 [==============================] - 273s 4s/step - loss: 0.7854 - acc: 0.2471 - val_loss: 0.8646 - val_acc: 0.2479
# Epoch 9/30
# 72/72 [==============================] - 273s 4s/step - loss: 0.7637 - acc: 0.2583 - val_loss: 0.8382 - val_acc: 0.2615
# Epoch 10/30
# 72/72 [==============================] - 273s 4s/step - loss: 0.7458 - acc: 0.2670 - val_loss: 0.8302 - val_acc: 0.2716
# Epoch 11/30
# 72/72 [==============================] - 271s 4s/step - loss: 0.7314 - acc: 0.2776 - val_loss: 0.8229 - val_acc: 0.2731
# Epoch 12/30
# 72/72 [==============================] - 275s 4s/step - loss: 0.7147 - acc: 0.2887 - val_loss: 0.8126 - val_acc: 0.2896
# Epoch 13/30
# 72/72 [==============================] - 274s 4s/step - loss: 0.6967 - acc: 0.3001 - val_loss: 0.8034 - val_acc: 0.2955
# Epoch 14/30
# 72/72 [==============================] - 276s 4s/step - loss: 0.6748 - acc: 0.3139 - val_loss: 0.8009 - val_acc: 0.3025
# Epoch 15/30
# 72/72 [==============================] - 273s 4s/step - loss: 0.6578 - acc: 0.3247 - val_loss: 0.7894 - val_acc: 0.3047
# Epoch 16/30
# 72/72 [==============================] - 271s 4s/step - loss: 0.6456 - acc: 0.3324 - val_loss: 0.7787 - val_acc: 0.3139
# Epoch 17/30
# 72/72 [==============================] - 271s 4s/step - loss: 0.6292 - acc: 0.3411 - val_loss: 0.7763 - val_acc: 0.3213
# Epoch 18/30
# 72/72 [==============================] - 271s 4s/step - loss: 0.6135 - acc: 0.3539 - val_loss: 0.7738 - val_acc: 0.3253
# Epoch 19/30
# 72/72 [==============================] - 272s 4s/step - loss: 0.5994 - acc: 0.3637 - val_loss: 0.7666 - val_acc: 0.3292
# Epoch 20/30
# 72/72 [==============================] - 273s 4s/step - loss: 0.5872 - acc: 0.3717 - val_loss: 0.7633 - val_acc: 0.3306
# Epoch 21/30
# 72/72 [==============================] - 273s 4s/step - loss: 0.5778 - acc: 0.3785 - val_loss: 0.7580 - val_acc: 0.3277
# Epoch 22/30
# 72/72 [==============================] - 274s 4s/step - loss: 0.5671 - acc: 0.3895 - val_loss: 0.7531 - val_acc: 0.3344
# Epoch 23/30
# 72/72 [==============================] - 271s 4s/step - loss: 0.5552 - acc: 0.3979 - val_loss: 0.7510 - val_acc: 0.3421
# Epoch 24/30
# 72/72 [==============================] - 273s 4s/step - loss: 0.5442 - acc: 0.4058 - val_loss: 0.7482 - val_acc: 0.3408
# Epoch 25/30
# 72/72 [==============================] - 277s 4s/step - loss: 0.5339 - acc: 0.4143 - val_loss: 0.7457 - val_acc: 0.3436
# Epoch 26/30
# 72/72 [==============================] - 274s 4s/step - loss: 0.5225 - acc: 0.4212 - val_loss: 0.7447 - val_acc: 0.3467
# Epoch 27/30
# 72/72 [==============================] - 277s 4s/step - loss: 0.5129 - acc: 0.4331 - val_loss: 0.7428 - val_acc: 0.3488
# Epoch 28/30
# 72/72 [==============================] - 277s 4s/step - loss: 0.4999 - acc: 0.4418 - val_loss: 0.7425 - val_acc: 0.3437
# Epoch 29/30
# 72/72 [==============================] - 275s 4s/step - loss: 0.4901 - acc: 0.4535 - val_loss: 0.7420 - val_acc: 0.3481
# Epoch 30/30
# 72/72 [==============================] - 277s 4s/step - loss: 0.4825 - acc: 0.4588 - val_loss: 0.7389 - val_acc: 0.3574

# %% [markdown]
# ###Saving Seq2Seq Model and Weights

# %%
model.save('eng-ara-model.hdf5')

# %%
model.save('/content/drive/MyDrive/eng-ara-model.hdf5')

# %%
model = keras.models.load_model('/content/drive/MyDrive/eng-ara-model.hdf5')

# %%
history2=model.fit_generator(generator = generate_batch(X_train, y_train, batch_size = batch_size),
                    steps_per_epoch = train_samples//batch_size,
                    epochs=epochs,
                    validation_data = generate_batch(X_test, y_test, batch_size = batch_size),
                    validation_steps = val_samples//batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/30
# 72/72 [==============================] - 291s 4s/step - loss: 0.4711 - acc: 0.4713 - val_loss: 0.7364 - val_acc: 0.3561
# Epoch 2/30
# 72/72 [==============================] - 281s 4s/step - loss: 0.4606 - acc: 0.4804 - val_loss: 0.7359 - val_acc: 0.3505
# Epoch 3/30
# 72/72 [==============================] - 280s 4s/step - loss: 0.4523 - acc: 0.4880 - val_loss: 0.7363 - val_acc: 0.3536
# Epoch 4/30
# 72/72 [==============================] - 280s 4s/step - loss: 0.4454 - acc: 0.4962 - val_loss: 0.7335 - val_acc: 0.3595
# Epoch 5/30
# 72/72 [==============================] - 280s 4s/step - loss: 0.4370 - acc: 0.5062 - val_loss: 0.7350 - val_acc: 0.3592
# Epoch 6/30
# 72/72 [==============================] - 280s 4s/step - loss: 0.4303 - acc: 0.5107 - val_loss: 0.7343 - val_acc: 0.3599
# Epoch 7/30
# 72/72 [==============================] - 278s 4s/step - loss: 0.4238 - acc: 0.5195 - val_loss: 0.7342 - val_acc: 0.3647
# Epoch 8/30
# 72/72 [==============================] - 279s 4s/step - loss: 0.4177 - acc: 0.5268 - val_loss: 0.7318 - val_acc: 0.3623
# Epoch 9/30
# 72/72 [==============================] - 279s 4s/step - loss: 0.4109 - acc: 0.5365 - val_loss: 0.7298 - val_acc: 0.3651
# Epoch 10/30
# 72/72 [==============================] - 280s 4s/step - loss: 0.4034 - acc: 0.5429 - val_loss: 0.7315 - val_acc: 0.3576
# Epoch 11/30
# 72/72 [==============================] - 278s 4s/step - loss: 0.3986 - acc: 0.5492 - val_loss: 0.7312 - val_acc: 0.3643
# Epoch 12/30
# 72/72 [==============================] - 279s 4s/step - loss: 0.3936 - acc: 0.5575 - val_loss: 0.7348 - val_acc: 0.3589
# Epoch 13/30
# 72/72 [==============================] - 278s 4s/step - loss: 0.3885 - acc: 0.5629 - val_loss: 0.7302 - val_acc: 0.3673
# Epoch 14/30
# 72/72 [==============================] - 276s 4s/step - loss: 0.3831 - acc: 0.5691 - val_loss: 0.7313 - val_acc: 0.3702
# Epoch 15/30
# 72/72 [==============================] - 274s 4s/step - loss: 0.3764 - acc: 0.5764 - val_loss: 0.7327 - val_acc: 0.3638
# Epoch 16/30
# 72/72 [==============================] - 275s 4s/step - loss: 0.3717 - acc: 0.5808 - val_loss: 0.7327 - val_acc: 0.3700
# Epoch 17/30
# 72/72 [==============================] - 274s 4s/step - loss: 0.3665 - acc: 0.5918 - val_loss: 0.7297 - val_acc: 0.3700
# Epoch 18/30
# 72/72 [==============================] - 275s 4s/step - loss: 0.3607 - acc: 0.5983 - val_loss: 0.7315 - val_acc: 0.3685
# Epoch 19/30
# 72/72 [==============================] - 275s 4s/step - loss: 0.3568 - acc: 0.6008 - val_loss: 0.7309 - val_acc: 0.3670
# Epoch 20/30
# 72/72 [==============================] - 273s 4s/step - loss: 0.3520 - acc: 0.6091 - val_loss: 0.7325 - val_acc: 0.3693
# Epoch 21/30
# 72/72 [==============================] - 274s 4s/step - loss: 0.3461 - acc: 0.6165 - val_loss: 0.7334 - val_acc: 0.3696
# Epoch 22/30
# 72/72 [==============================] - 273s 4s/step - loss: 0.3431 - acc: 0.6198 - val_loss: 0.7343 - val_acc: 0.3712
# Epoch 23/30
# 72/72 [==============================] - 274s 4s/step - loss: 0.3382 - acc: 0.6238 - val_loss: 0.7337 - val_acc: 0.3703
# Epoch 24/30
# 72/72 [==============================] - 275s 4s/step - loss: 0.3351 - acc: 0.6283 - val_loss: 0.7343 - val_acc: 0.3698
# Epoch 25/30
# 72/72 [==============================] - 277s 4s/step - loss: 0.3312 - acc: 0.6340 - val_loss: 0.7328 - val_acc: 0.3717
# Epoch 26/30
# 72/72 [==============================] - 274s 4s/step - loss: 0.3271 - acc: 0.6396 - val_loss: 0.7338 - val_acc: 0.3728
# Epoch 27/30
# 72/72 [==============================] - 275s 4s/step - loss: 0.3239 - acc: 0.6444 - val_loss: 0.7365 - val_acc: 0.3745
# Epoch 28/30
# 72/72 [==============================] - 275s 4s/step - loss: 0.3204 - acc: 0.6485 - val_loss: 0.7378 - val_acc: 0.3710
# Epoch 29/30
# 72/72 [==============================] - 275s 4s/step - loss: 0.3171 - acc: 0.6501 - val_loss: 0.7389 - val_acc: 0.3654
# Epoch 30/30
# 72/72 [==============================] - 276s 4s/step - loss: 0.3140 - acc: 0.6544 - val_loss: 0.7380 - val_acc: 0.3672

# %%
model.save('/content/drive/MyDrive/eng-ara-model.hdf5')

# %%
model.save_weights('eng-ara-weights.hdf5')

# %%
model.save_weights('/content/drive/MyDrive/eng-ara-weights.hdf5')

# %%
model = keras.models.load_model('/content/drive/MyDrive/eng-ara-model.hdf5')

# %% [markdown]
# ###Inference Model

# %%
# Encode the input sequence to get the "Context vectors"
encoder_model = Model(encoder_inputs, encoder_states)
# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_state_input = [decoder_state_input_h, decoder_state_input_c]
# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs)
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=decoder_state_input)
decoder_states2 = [state_h2, state_c2]
# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_outputs2)
# Final decoder model
decoder_model = Model(
    [decoder_inputs] + decoder_state_input,
    [decoder_outputs2] + decoder_states2)

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    # Populate the first character of 
    #target sequence with the start character.
    target_seq[0, 0] = target_word2idx['START_']
# Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)
# Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word =target_idx2word[sampled_token_index]
        decoded_sentence += ' '+ sampled_word
# Exit condition: either hit max length
        # or find stop character.
        if (sampled_word == '_END' or
           len(decoded_sentence) > 50):
            stop_condition = True
# Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index
# Update states
        states_value = [h, c]
    return decoded_sentence

# %% [markdown]
# ### Evaluation on Train Dataset

# %%
train_gen = generate_batch(X_train, y_train, batch_size = 1)
k=-1

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input Source sentence:', X_train[k:k+1].values[0])
print('Actual Target Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Target Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input Source sentence: im not going back
# Actual Target Translation:  لن اعود
# Predicted Target Translation:  لن اذهب
# 0.816496580927726
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: im walking with her
# Actual Arabic Translation:  اني اتمشي معها
# Predicted Arabic Translation:  انا فقدت سيارتي
# 0.7364279629037999
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: clean the window with a damp cloth
# Actual Arabic Translation:  نظف زجاج النافذه بقطعه قماش مبلوله
# Predicted Arabic Translation:  ابق ماري ابق تحت ملء به
# 0.727427152512826
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: theres no reason tom would say something like that
# Actual Arabic Translation:  لا سبب يدفع توم لقول شيء كهذا
# Predicted Arabic Translation:  لا يستطيع توم ان يفعل ذلك ما يكفي
# 0.7652058832556895
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: i got wet to the skin
# Actual Arabic Translation:  بلغ البلل بدني
# Predicted Arabic Translation:  اخلع نحصل علي
# 0.7598356856515925
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: they are very big
# Actual Arabic Translation:  انهم كبار جدا
# Predicted Arabic Translation:  نحن تبدو جدا
# 0.8091067115702212
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: he believes whatever i say
# Actual Arabic Translation:  هو يصدق اي شئ اقوله
# Predicted Arabic Translation:  انه يريد ان يكون لا شيء
# 0.7521206186172787
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: please remove your shoes before entering the house
# Actual Arabic Translation:  من فضلك اخلع حذاءك قبل ان تدخل البيت
# Predicted Arabic Translation:  من فضلك اخلع حذاءك قبل ان البيت
# 0.8471957049969466
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: we arent going to lose
# Actual Arabic Translation:  لن نخسر
# Predicted Arabic Translation:  لن يغير ابدا
# 0.7311104457090247
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: has something happened
# Actual Arabic Translation:  هل حدث اي شيء
# Predicted Arabic Translation:  هل شيء ما حدث
# 0.9036020036098448
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_test[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: dont leave me alone please
# Actual Arabic Translation:  لا تتركني لوحدي ارجوك
# Predicted Arabic Translation:  لا تنس الباب من فضلك
# 0.6904573083274563
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: tom has a stuffedup nose
# Actual Arabic Translation:  انف توم محتقن
# Predicted Arabic Translation:  توم لديه كبيره
# 0.7071067811865476
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: im not allowed to tell what you want to know
# Actual Arabic Translation:  لم يؤذن لي باطلاعك علي ما تريد معرفته
# Predicted Arabic Translation:  لا اريد ان اقول شيئا ما لم اكن لي لك
# 0.697613262053043
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: im trying to find a way to make money
# Actual Arabic Translation:  احاول العثور علي طريقه لجمع الاموال
# Predicted Arabic Translation:  انا احاول ان اساعدك في الوقت
# 0.7186082239261684
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: the man aimed a gun at the detectives
# Actual Arabic Translation:  صوب الرجل مسدسا نحو المحققين
# Predicted Arabic Translation:  لقد لقد كان توم في الغرفه
# 0.7801157731069053
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: california is famous for its fruit
# Actual Arabic Translation:  اشتهرت كاليفورنيا بفواكهها
# Predicted Arabic Translation:  ليس وقت كبيره
# 0.8801117367933934
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: im looking forward to your halloween party
# Actual Arabic Translation:  انا اتتطلع لحفله الهالوين خاصتك
# Predicted Arabic Translation:  انا اتتطلع لحفله مع توم
# 0.8144476398584994
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: i like studying languages
# Actual Arabic Translation:  احب تعلم اللغات
# Predicted Arabic Translation:  احب قراءه الكتب
# 0.7707713836060629
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: wheres your money
# Actual Arabic Translation:  اين مالكم
# Predicted Arabic Translation:  اين اقرب
# 0.7952707287670506
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: he narrowly escaped death
# Actual Arabic Translation:  نجا من الموت باعجوبه
# Predicted Arabic Translation:  لقد كانت الشرطه علي قدميه
# 0.7377879464668811
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_test[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: at first it is difficult
# Actual Arabic Translation:  انها صعبه في البدايه
# Predicted Arabic Translation:  انها في العالم
# 0.8660254037844387
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: speaking english isnt easy
# Actual Arabic Translation:  التحدث بالانجليزيه ليس امرا سهلا
# Predicted Arabic Translation:  الانجليزيه ليست الانجليزيه
# 0.7730551756939454
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: because hes sick he cant come
# Actual Arabic Translation:  لن يستطيع المجيء لانه مريض
# Predicted Arabic Translation:  لن يكون من الممكن ان يكون يكون ذلك كثيرا
# 0.6389431042462724
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_test[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: stop teasing your brother
# Actual Arabic Translation:  توقفي عن غيظ اخيك
# Predicted Arabic Translation:  توقف عن غيظ اخيك
# 0.7259795291154771
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: i do love you
# Actual Arabic Translation:  احبك
# Predicted Arabic Translation:  انا احبك
# 0.8408964152537145
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: she rarely goes out on sundays
# Actual Arabic Translation:  نادرا ما تخرج ايام الاحد
# Predicted Arabic Translation:  كل ما يكون علي توم في السرير
# 0.7186082239261684
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: you shouldve started by now
# Actual Arabic Translation:  كان عليك ان تكون قد بدات الان
# Predicted Arabic Translation:  كان عليك ان تكون في المنزل
# 0.7529586373193689
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: my father bought me a bicycle
# Actual Arabic Translation:  اشتري لي ابي دراجه
# Predicted Arabic Translation:  ابي ابي ابي علي البيانو
# 0.668740304976422
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: why dont we do that right now
# Actual Arabic Translation:  لم لا نقوم بذلك للتو
# Predicted Arabic Translation:  لم لا تنس ذلك بذلك
# 0.81903625881272
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_test[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: bring me a cup of coffee will you
# Actual Arabic Translation:  احضر لي فنجانا من القهوه
# Predicted Arabic Translation:  احضر لي كاسا من القهوه
# 0.7071067811865476
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: my son is a rebellious teenager
# Actual Arabic Translation:  ابني مراهق متمرد
# Predicted Arabic Translation:  امي امي
# 0.816496580927726
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_test[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: we feel good about it
# Actual Arabic Translation:  نتفائل به
# Predicted Arabic Translation:  نحن نحن لديك بك
# 0.7364279629037999
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_train[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: may i interrupt
# Actual Arabic Translation:  هل لي ان اقاطع
# Predicted Arabic Translation:  هل يمكنني ان اساعدك
# 0.7598356856515925
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_test[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: this is toms favorite book
# Actual Arabic Translation:  هذا كتاب توم المفضل
# Predicted Arabic Translation:  توم هو في هذا المنزل
# 0.7765453555044466
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: dont lie
# Actual Arabic Translation:  اياك والكذب
# Predicted Arabic Translation:  لا تلمسني

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: i had my brother repair my bicycle
# Actual Arabic Translation:  طلبت من اخي اصلاح دراجتي
# Predicted Arabic Translation:  طلبت علي ان اخي طبيبا

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: but youre not there
# Actual Arabic Translation:  لكنك لست هناك
# Predicted Arabic Translation:  لن يكن هذا شيء

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: water freezes at zero degrees celsius doesnt it
# Actual Arabic Translation:  يتجمد الماء عند صفر درجه مئويه اليس كذلك
# Predicted Arabic Translation:  لا يستطيع ابي في الجزء ماذا يفعل هذا

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: i wonder where tom is and who hes with
# Actual Arabic Translation:  انا اتساءل اين توم ومع من
# Predicted Arabic Translation:  انا لا اعرف توم في بوسطن

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: i need to charge my cell phone
# Actual Arabic Translation:  علي شحن هاتفي الجوال
# Predicted Arabic Translation:  احتاج الي مساعدتك

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: you can skate safely on this side of the lake
# Actual Arabic Translation:  يمكنك التزلج بامان علي هذا الجانب من البحيره
# Predicted Arabic Translation:  يمكنك ان تدرس في المحطه لا يمكنك او هذا

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: she was at the crime scene
# Actual Arabic Translation:  انها كانت في موقع الجريمه
# Predicted Arabic Translation:  كان علي وشك في المنزل

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: tom doesnt hate you mary
# Actual Arabic Translation:  توم لا يكرهك ياماري
# Predicted Arabic Translation:  توم لا يستطيع ان يكون ماري

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: thats a good question
# Actual Arabic Translation:  هذا سؤال جيد
# Predicted Arabic Translation:  هذا جيد جدا

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: please keep this secret
# Actual Arabic Translation:  من فضلك ابق ذلك سرا
# Predicted Arabic Translation:  من فضلك ابق هذه الصفحه

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: he has been warned on several occasions
# Actual Arabic Translation:  قد انذر مرات عديده
# Predicted Arabic Translation:  لقد كان علي ان تقود توم

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: they kept it secret that they were in love
# Actual Arabic Translation:  ابقو حبهما سرا
# Predicted Arabic Translation:  لقد لقد كنت كنت في الوقت

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: if we leave now we should make it
# Actual Arabic Translation:  ان غادرنا الان فسنصل علي الوقت
# Predicted Arabic Translation:  علينا ان اكون الوقت ان تكون اكثر من الوقت

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: i just wish i knew how to speak french
# Actual Arabic Translation:  اتمنتي فقط لو استطعت تكلم الفرنسيه
# Predicted Arabic Translation:  اريد ان اعرف كيف تكون في الفرنسيه

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: it was at school
# Actual Arabic Translation:  كان في المدرسه
# Predicted Arabic Translation:  كان في المنزل

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: the rain is wonderful
# Actual Arabic Translation:  المطر رائع
# Predicted Arabic Translation:  توقف عن غيظ ذلك

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: do you have a car
# Actual Arabic Translation:  هل عندك سياره
# Predicted Arabic Translation:  هل لديك سياره

# %%
k+=1
(input_seq, actual_output), _ = next(train_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_train[k:k+1].values[0])
print('Actual Arabic Translation:', y_train[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: can you see the difference
# Actual Arabic Translation:  هل بامكانك ان تري الفرق
# Predicted Arabic Translation:  ايمكنك ان تخبرني معي

# %% [markdown]
# ### Evaluation on Test Dataset

# %%
val_gen = generate_batch(X_test, y_test, batch_size = 1)
k=-1

# %%
test_gen = generate_batch(X_test, y_test, batch_size = 1)
k=10
k+=1
(input_seq, actual_output), _ = next(test_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input Source sentence:', X_test[k:k+1].values[0])
print('Actual Target Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Target Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_test[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input Source sentence: he thinks i love her
# Actual Target Translation:  هو يعتقد انني احبها
# Predicted Target Translation:  لديه ثلاثه ثلاثه
# 0.7259795291154771
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_test[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: fish is cheap today
# Actual Arabic Translation:  السمك رخيص اليوم
# Predicted Arabic Translation:  لديه ثلاثه ثلاثه
# 0.6865890479690392
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_test[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: tom felt strong
# Actual Arabic Translation:  توم شعر بالقوه
# Predicted Arabic Translation:  لا يمكنني ان تكون هذه المساله
# 0.6893409630302637
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_test[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: i think thats what happened
# Actual Arabic Translation:  اظن ان هذا ما حدث
# Predicted Arabic Translation:  انها سعيده
# 0.8034284189446518
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: my uncle gave me a camera
# Actual Arabic Translation:  اعطاني عمي كاميرا
# Predicted Arabic Translation:  كان توم وماري جدا

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_test[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: youre doing it wrong
# Actual Arabic Translation:  انت تفعله بطريقه خاطئه
# Predicted Arabic Translation:  دعونا نتقاسم التلفاز
# 0.7765453555044466
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_test[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: i was at a movie theater
# Actual Arabic Translation:  كنت في دور عرض للسينما
# Predicted Arabic Translation:  انها تحب كره المضرب
# 0.8091067115702212
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_test[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: their trip was postponed because of the rain
# Actual Arabic Translation:  تاجلت رحلتهم بسبب المطر
# Predicted Arabic Translation:  توم ماري ماري في ماري ما
# 0.6622152291011697
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: what do you want now
# Actual Arabic Translation:  ما الذي تريده الان
# Predicted Arabic Translation:  الجميع

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_test[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: the internet is very useful for knowing the circumstances of each part of the world
# Actual Arabic Translation:  الانترنت مفيد جدا لمعرفه ظروف كل جزء من العالم
# Predicted Arabic Translation:  هل سبق ان تقود سياره كبيره
# 0.7916963878457504
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_test[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: i have a car
# Actual Arabic Translation:  املك سياره
# Predicted Arabic Translation:  انها ان وسيم
# 0.8091067115702212
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_test[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: none of my classmates live near here
# Actual Arabic Translation:  لا احد من زملائي يعيشون بالقرب من هنا
# Predicted Arabic Translation:  ما الذي تفعله
# 0.8265168183793802
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: stop it right now
# Actual Arabic Translation:  اوقف هذا حالا
# Predicted Arabic Translation:  انه يحب الجميع

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: i have no words to express my gratitude
# Actual Arabic Translation:  الكلمات لا يمكنها التعبير عن شكري بما يكفي
# Predicted Arabic Translation:  الصين بلد جميل

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: this way sir
# Actual Arabic Translation:  من هنا سيدي
# Predicted Arabic Translation:  توم يحب السفر

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: there is no reason why i shouldnt do it
# Actual Arabic Translation:  لا يوجد سبب لئلا افعله
# Predicted Arabic Translation:  اعتقد انه كان ما حدث

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: we dont know where well live next year
# Actual Arabic Translation:  نحن لا نعرف اين سنعيش في العام المقبل
# Predicted Arabic Translation:  لي لي امي امي

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: i cant live without you
# Actual Arabic Translation:  لا استطيع العيش من دونك
# Predicted Arabic Translation:  انت انت محق

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: im tired of watching tv
# Actual Arabic Translation:  انا تعب من مشاهده التلفاز
# Predicted Arabic Translation:  كنت في المنزل جديده

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: i had better ask her
# Actual Arabic Translation:  من الافضل ان اسئلها
# Predicted Arabic Translation:  بسبب العاصفه بسبب توم

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: i want to look rich
# Actual Arabic Translation:  اريد ان ابدو غنيا
# Predicted Arabic Translation:  ماذا تريد الان

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: would you like to go to the zoo this afternoon
# Actual Arabic Translation:  هل تريد ان تذهب الي حديقه الحيوان بعد ظهر هذا اليوم
# Predicted Arabic Translation:  هذه بلد هي العالم جدا

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: i dont believe that tom is the killer
# Actual Arabic Translation:  لا اصدق ان توم هو القاتل
# Predicted Arabic Translation:  لدي سياره

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: you have a bright future
# Actual Arabic Translation:  لديك مستقبل واعد
# Predicted Arabic Translation:  لا احد في اي شيء في نفس شيء

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: is it possible that its already eight oclock
# Actual Arabic Translation:  هل من الممكن انها بالفعل الساعه الثامنه
# Predicted Arabic Translation:  سوف يكون مجددا

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: that child is only four but he can already count to
# Actual Arabic Translation:  بامكان هذا الطفل ان يعد الي مئه مع انه ما زال لديه اربع سنوات
# Predicted Arabic Translation:  لا يمكنني ان اصدق عن هذه المشكله

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: its only a theory
# Actual Arabic Translation:  انها مجرد نظريه
# Predicted Arabic Translation:  هذه القلعه جميله

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: im really tired
# Actual Arabic Translation:  انا متعب جدا
# Predicted Arabic Translation:  لا يوجد اي شيء تريد ان فعل ذلك

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: where is the book
# Actual Arabic Translation:  اين الكتاب
# Predicted Arabic Translation:  لا اعرف في ما الذي تعمل

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: few people know about the plan
# Actual Arabic Translation:  القليل يعرف اي شيء عن الخطه
# Predicted Arabic Translation:  لا يمكنني ان تكون غبيا

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: i really didnt mean to hurt you
# Actual Arabic Translation:  لم اقصد ان اوذيك
# Predicted Arabic Translation:  انا مشغول جدا

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: tom paid for the tickets
# Actual Arabic Translation:  دفع توم ثمن التذاكر
# Predicted Arabic Translation:  لم يكن لدي الكثير من

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: i think youre right
# Actual Arabic Translation:  اظن انك محق
# Predicted Arabic Translation:  اريد ان اكون

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: is it rainy
# Actual Arabic Translation:  هل الجو ممطر
# Predicted Arabic Translation:  هل يمكنني ان تخبرني هذا الكتاب جديده

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: im sorry but i dont want to talk about it
# Actual Arabic Translation:  المعذره لا اريد التحدث عن الموضوع
# Predicted Arabic Translation:  لا اصدق ان توم هو ذلك

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: i know i dont have any chance of winning
# Actual Arabic Translation:  اعلم بانه ليس لدي اي فرصه للفوز
# Predicted Arabic Translation:  انت لديك لديك

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: can you suggest a better idea
# Actual Arabic Translation:  ايمكنك ان تقترح فكره افضل
# Predicted Arabic Translation:  هل لديك اي شيء علي ان يكون توم

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: this drawing dates back to the fifteenth century
# Actual Arabic Translation:  هذا الرسم يعود تاريخه الي القرن الخامس عشر
# Predicted Arabic Translation:  كل ما هو يستطيع ان يكون توم في الفرنسيه

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: how much longer is it going to take
# Actual Arabic Translation:  كم من الوقت سوف تستغرق بعد
# Predicted Arabic Translation:  انه ليس هذه كبيره

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: she dived into the swimming pool
# Actual Arabic Translation:  غطست في المسبح
# Predicted Arabic Translation:  انا سعيد جدا

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: its recommended that you dont write your passwords down where others might see them
# Actual Arabic Translation:  من الافضل الا تكتب كلمات المرور كي لا يراها الغير
# Predicted Arabic Translation:  اين هي

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: i didnt even recognize tom
# Actual Arabic Translation:  انا حتي لم اعرف انه توم
# Predicted Arabic Translation:  القليل من دون واحد

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: please write with a pen
# Actual Arabic Translation:  من فضلك اكتب بقلم حبر
# Predicted Arabic Translation:  لم اكن اعرف كيف اقول

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: im going through changes
# Actual Arabic Translation:  امر بتغيرات
# Predicted Arabic Translation:  توم كان في الخارج من قبل

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: this question is one of great importance
# Actual Arabic Translation:  هذا سؤال مهم جدا
# Predicted Arabic Translation:  اظن انك لا استطيع

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: turn down the tv
# Actual Arabic Translation:  اخفض صوت التلفاز
# Predicted Arabic Translation:  هل الجو بارد

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: tom often goes to boston
# Actual Arabic Translation:  يذهب توم الي بوسطن كثيرا
# Predicted Arabic Translation:  انا لا اريد ان انسي هذا لا شئ

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: i bet everyone is waiting
# Actual Arabic Translation:  انا متاكد ان الجميع ينتظر
# Predicted Arabic Translation:  لا اعرف لدي اي شيء من قبل ان لا احب عنه

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
# Out:
# Input English sentence: that book had a lot of pages
# Actual Arabic Translation:  صفحات ذلك الكتاب كثيره
# Predicted Arabic Translation:  ايمكنك ان تخبرني كيف تقود سياره

# %%
k+=1
(input_seq, actual_output), _ = next(val_gen)
decoded_sentence = decode_sequence(input_seq)
print('Input English sentence:', X_test[k:k+1].values[0])
print('Actual Arabic Translation:', y_test[k:k+1].values[0][6:-4])
print('Predicted Arabic Translation:', decoded_sentence[:-4])
score1 = sentence_bleu(y_test[k:k+1].values[0][6:-4],decoded_sentence[:-4])
print(score1)
# Out:
# Input English sentence: what kind of a person are you
# Actual Arabic Translation:  اي نوع من الاشخاص انت
# Predicted Arabic Translation:  القطه هذه السياح الي العالم
# 0.6744322250214191
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %% [markdown]
# ###BLUE score

# %%
actual,predicted=list(),list()
val_gen = generate_batch(X_test, y_test, batch_size = 1)
for k in range(len(X_test)):
  (input_seq, actual_output), _ = next(val_gen)
  decoded_sentence = decode_sequence(input_seq)
  actual.append(y_test[k:k+1].values[0][6:-4])
  predicted.append(decoded_sentence[:-4])

# %%
#Blue score
bs=0
for i in range(len(actual)):
  score1 = sentence_bleu(actual[i],predicted[i])
  bs=bs+score1
bs=bs/len(actual)
print('Bleu score on Test set:', bs)
# Out:
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Bleu score on Test set: 0.7759777657294306

# %%
  # calculate BLEU score with weights
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))
# Out:
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# BLEU-1: 0.347446
# BLEU-2: 0.589445
# BLEU-3: 0.728226
# BLEU-4: 0.767753

# %% [markdown]
# ###References

# %% [markdown]
# Some parts of the code were taken from the following references:
# 1-https://towardsdatascience.com/how-to-implement-seq2seq-lstm-model-in-keras-shortcutnlp-6f355f3e5639
# 2-https://github.com/motazsaad/process-arabic-text/blob/master/clean_arabic_text.py
# 3-https://towardsdatascience.com/implementing-neural-machine-translation-using-keras-8312e4844eb8
# 4-https://keras.io/examples/nlp/lstm_seq2seq/
# 5-https://machinelearningmastery.com/develop-neural-machine-translation-system-keras/
# 6-https://www.kaggle.com/thanakomsn/glove6b300dtxt
# 7-https://towardsdatascience.com/word-level-english-to-marathi-neural-machine-translation-using-seq2seq-encoder-decoder-lstm-model-1a913f2dc4a7
